# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization,concatenate,UpSampling2D,Dropout
from tensorflow.keras.models import Model
import tensorflow as tf 
from tensorflow.keras.layers import Input, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, Concatenate, Activation, Add, multiply, add, concatenate, LeakyReLU, ZeroPadding2D, UpSampling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K 
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
mkdir checkpoints

# %%
X = np.load("../input/teeth-segmentation-npy-files/X.npy")
Y = np.load("../input/teeth-segmentation-npy-files/Y.npy")
X.shape, Y.shape
# Out:
# ((464, 512, 512, 1), (464, 512, 512, 1))

# %%
# X = np.reshape(X, (-1,1,512,512))
# X.shape
# Y = np.reshape(Y, (-1,1,512,512))
# Y.shape

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, 
                                                    shuffle=True, 
                                                    random_state=42)

# %%
del X
del Y

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((371, 512, 512, 1), (93, 512, 512, 1), (371, 512, 512, 1), (93, 512, 512, 1))

# %%
#### Attention UNet

def conv_block(x, filter_size, size, dropout, batch_norm = False):
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    return conv


def repeat_elem(tensor, rep):
     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': rep})(tensor)


def gating_signal(input, out_size, batch_norm = False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x


def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
    
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)
    shape_theta_x = K.int_shape(theta_x)

    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(
        inter_shape, 
        (3, 3),
        strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
        padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn



def Attention_UNet():
    # hyper parameters
    dropout_rate = 0.2
    batch_norm = True
    
    # network structure
    f = [16, 32, 64, 128, 256, 512, 1024]
    
    inputs = layers.Input(shape = (512, 512, 1))

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, 3, f[0], dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, 3, f[1], dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, 3, f[2], dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, 3, f[3], dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5
    conv_8 = conv_block(pool_8, 3, f[4], dropout_rate, batch_norm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(conv_8)
    # DownRes 6
    conv_4 = conv_block(pool_4, 3, f[5], dropout_rate, batch_norm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_4)
    # DownRes 7
    conv_2 = conv_block(pool_2, 3, f[6], dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 5
    gating_4 = gating_signal(conv_2, f[5], batch_norm)
    att_4 = attention_block(conv_4, gating_4, f[5])
    up_4 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(conv_2)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = conv_block(up_4, 3, f[5], dropout_rate, batch_norm)
    
    # UpRes 6
    gating_8 = gating_signal(conv_4, f[4], batch_norm)
    att_8 = attention_block(conv_8, gating_8, f[4])
    up_8 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_4)
    up_8 = layers.concatenate([up_8, att_8], axis=3)
    up_conv_8 = conv_block(up_8, 3, f[4], dropout_rate, batch_norm)
    
    # UpRes 6
    gating_16 = gating_signal(up_conv_8, f[3], batch_norm)
    att_16 = attention_block(conv_16, gating_16, f[3])
    up_16 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, 3, f[3], dropout_rate, batch_norm)

    # UpRes 7
    gating_32 = gating_signal(up_conv_16, f[2], batch_norm)
    att_32 = attention_block(conv_32, gating_32, f[2])
    up_32 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, 3, f[2], dropout_rate, batch_norm)
    
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, f[1], batch_norm)
    att_64 = attention_block(conv_64, gating_64, f[1])
    up_64 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, 3, f[1], dropout_rate, batch_norm)
    
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, f[0], batch_norm)
    att_128 = attention_block(conv_128, gating_128, f[0])
    up_128 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, 3, f[0], dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis = 3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel


    # Model integration
    model = keras.models.Model(inputs, conv_final, name="Attention_UNet")
    return model

model = Attention_UNet()
model.summary()
# Out:
# 2022-09-23 16:16:45.121533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:45.229346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:45.230147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:45.232120: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-23 16:16:45.232472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:45.233189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:45.233825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:47.671177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:47.671994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:47.672705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-23 16:16:47.673297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512, 512, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512, 512, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512, 512, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512, 512, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 16) 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 64) 36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 64) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 512)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 512)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 1024)   9438208     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 1024)   4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 1024)   0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    524800      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 512)    262656      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 512)    2359808     conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 512)    1049088     dropout_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 512)    0           conv2d_transpose[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 512)    0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 1)      513         activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 1)      0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 1)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 256)  131328      dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16, 16, 512)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 256)  1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 16, 16, 512)  0           lambda[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 512)  262656      multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 256)  65792       activation_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 1024) 0           dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 512)  2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 256)  590080      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 256)  262400      dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1536) 0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 512)  7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 512)  2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 1)    257         activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 512)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 1)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 512)  2359808     activation_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 1)    0           activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 256)  0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 512)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 32, 32, 256)  0           lambda_1[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 512)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 256)  65792       multiply_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 512)  0           dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 256)  1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 768)  0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 256)  0           activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 128)  32896       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 128)  16512       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 128)  147584      conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 128)  65664       dropout_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 1)    129         activation_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 1)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 1)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 64, 128)  0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 64, 64, 128)  0           lambda_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 128)  16512       multiply_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 256)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 384)  0           up_sampling2d_5[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 128)  147584      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 128)  0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 64)   8256        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 64)   4160        activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   36928       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 64)   16448       dropout_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 1)    65          activation_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 1)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 1)  0           activation_31[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128, 128, 64) 0           up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 128, 128, 64) 0           lambda_3[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 64) 4160        multiply_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 128 0           dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 64) 256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 192 0           up_sampling2d_7[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 128, 128, 64) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 64) 36928       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 128, 128, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 64) 0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 32) 2080        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 32) 128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 128, 128, 32) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 32) 1056        activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 32) 9248        conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 32) 4128        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 128, 128, 32) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 1)  33          activation_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 128, 128, 1)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 1)  0           activation_36[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 256, 256, 32) 0           up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 256, 256, 32) 0           lambda_4[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 256, 256, 32) 1056        multiply_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 64) 0           dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 256, 256, 32) 128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 96) 0           up_sampling2d_9[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 32) 27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 256, 256, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 256, 256, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 32) 9248        activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 256, 256, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 256, 256, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 256, 256, 32) 0           activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 256, 256, 16) 528         dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 256, 256, 16) 64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 256, 256, 16) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 16) 272         activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 16) 2320        conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 256, 256, 16) 1040        dropout[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 256, 16) 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 256, 256, 16) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 1)  17          activation_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 256, 256, 1)  0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 512, 512, 1)  0           activation_41[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 512, 512, 16) 0           up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 512, 512, 16) 0           lambda_5[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 512, 512, 16) 272         multiply_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 512, 512, 32) 0           dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 512, 512, 16) 64          conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 512, 512, 48) 0           up_sampling2d_11[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 512, 512, 16) 6928        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 512, 512, 16) 64          conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 512, 512, 16) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 512, 512, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 512, 512, 16) 64          conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 512, 512, 16) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512, 512, 16) 0           activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 512, 512, 1)  17          dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 512, 512, 1)  4           conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 512, 512, 1)  0           batch_normalization_38[0][0]
# ==================================================================================================
# Total params: 37,437,067
# Trainable params: 37,420,873
# Non-trainable params: 16,194
# __________________________________________________________________________________________________

# %%
from keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return(2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def IOU(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    
    return intersection/union

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred, 1)

def specificity(y_true, y_pred):
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    return tn / (tn + fp + K.epsilon())

# %%
import tensorflow as tf
model_ckt = tf.keras.callbacks.ModelCheckpoint(
    "./checkpoints/",
    monitor='val_accuracy',
    verbose = 1,
    save_best_only=False,
    save_weights_only=True,
    mode='max',
    save_freq='epoch',
)
learningrate_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                           mode = 'max',
                                                           factor = 0.1, 
                                                           patience = 20, 
                                                           verbose = 1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', 
                                                 patience = 20, 
                                                 mode = 'max',
                                                 restore_best_weights = True,
                                                  verbose=1)

callbacks_list = [learningrate_scheduler, early_stopping, model_ckt]

# %%
import tensorflow as tf
import tensorflow_addons as tfa
model.compile(optimizer =tf.keras.optimizers.Adam(learning_rate = 0.01), 
              loss = 'binary_crossentropy', 
              metrics = ['accuracy', dice_coef, IOU, specificity,
                         tf.keras.metrics.Recall(name='recall'),
                         tf.keras.metrics.Precision(name='precision')])

history = model.fit(X_train, Y_train,
          validation_data=(X_test, Y_test),
          batch_size=8,
          epochs=200,
          verbose=1,
          callbacks = callbacks_list)
# Out:
# 2022-09-23 16:17:04.535526: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-09-23 16:17:13.079383: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 47/47 [==============================] - 38s 439ms/step - loss: 0.4896 - accuracy: 0.7902 - dice_coef: 0.4423 - IOU: 0.2868 - specificity: 0.8736 - recall: 0.6948 - precision: 0.6571 - val_loss: 391617.8125 - val_accuracy: 0.1633 - val_dice_coef: 0.3516 - val_IOU: 0.2135 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_precision: 0.2477
#
# Epoch 00001: saving model to ./checkpoints/
# Epoch 2/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.2978 - accuracy: 0.8733 - dice_coef: 0.5864 - IOU: 0.4154 - specificity: 0.9464 - recall: 0.8315 - precision: 0.8705 - val_loss: 3.3099 - val_accuracy: 0.6022 - val_dice_coef: 0.4480 - val_IOU: 0.2889 - val_specificity: 0.5860 - val_recall: 0.8994 - val_precision: 0.4256
#
# Epoch 00002: saving model to ./checkpoints/
# Epoch 3/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.2310 - accuracy: 0.8813 - dice_coef: 0.6566 - IOU: 0.4893 - specificity: 0.9597 - recall: 0.8163 - precision: 0.9026 - val_loss: 0.5514 - val_accuracy: 0.7585 - val_dice_coef: 0.1829 - val_IOU: 0.1008 - val_specificity: 0.9989 - val_recall: 0.0362 - val_precision: 0.9385
#
# Epoch 00003: saving model to ./checkpoints/
# Epoch 4/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.1978 - accuracy: 0.8841 - dice_coef: 0.6981 - IOU: 0.5365 - specificity: 0.9649 - recall: 0.8061 - precision: 0.9160 - val_loss: 0.6289 - val_accuracy: 0.7523 - val_dice_coef: 0.1034 - val_IOU: 0.0545 - val_specificity: 1.0000 - val_recall: 6.4077e-05 - val_precision: 1.0000
#
# Epoch 00004: saving model to ./checkpoints/
# Epoch 5/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.1728 - accuracy: 0.8879 - dice_coef: 0.7321 - IOU: 0.5776 - specificity: 0.9702 - recall: 0.8041 - precision: 0.9300 - val_loss: 0.6135 - val_accuracy: 0.7523 - val_dice_coef: 0.1115 - val_IOU: 0.0590 - val_specificity: 1.0000 - val_recall: 1.5862e-04 - val_precision: 1.0000
#
# Epoch 00005: saving model to ./checkpoints/
# Epoch 6/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.1592 - accuracy: 0.8896 - dice_coef: 0.7547 - IOU: 0.6062 - specificity: 0.9721 - recall: 0.8049 - precision: 0.9349 - val_loss: 0.6313 - val_accuracy: 0.7523 - val_dice_coef: 0.1022 - val_IOU: 0.0538 - val_specificity: 1.0000 - val_recall: 6.3912e-05 - val_precision: 1.0000
#
# Epoch 00006: saving model to ./checkpoints/
# Epoch 7/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.1427 - accuracy: 0.8933 - dice_coef: 0.7765 - IOU: 0.6349 - specificity: 0.9747 - recall: 0.8133 - precision: 0.9445 - val_loss: 0.6480 - val_accuracy: 0.7523 - val_dice_coef: 0.0942 - val_IOU: 0.0494 - val_specificity: 1.0000 - val_recall: 9.2722e-06 - val_precision: 1.0000
#
# Epoch 00007: saving model to ./checkpoints/
# Epoch 8/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.1361 - accuracy: 0.8938 - dice_coef: 0.7893 - IOU: 0.6520 - specificity: 0.9766 - recall: 0.8075 - precision: 0.9490 - val_loss: 0.4745 - val_accuracy: 0.7740 - val_dice_coef: 0.2923 - val_IOU: 0.1716 - val_specificity: 0.9991 - val_recall: 0.1139 - val_precision: 0.9901
#
# Epoch 00008: saving model to ./checkpoints/
# Epoch 9/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1288 - accuracy: 0.8951 - dice_coef: 0.8013 - IOU: 0.6686 - specificity: 0.9769 - recall: 0.8139 - precision: 0.9501 - val_loss: 0.5957 - val_accuracy: 0.7543 - val_dice_coef: 0.1402 - val_IOU: 0.0754 - val_specificity: 1.0000 - val_recall: 0.0104 - val_precision: 0.9989
#
# Epoch 00009: saving model to ./checkpoints/
# Epoch 10/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1239 - accuracy: 0.8959 - dice_coef: 0.8089 - IOU: 0.6793 - specificity: 0.9771 - recall: 0.8160 - precision: 0.9518 - val_loss: 0.3883 - val_accuracy: 0.8003 - val_dice_coef: 0.4311 - val_IOU: 0.2756 - val_specificity: 0.9979 - val_recall: 0.2484 - val_precision: 0.9911
#
# Epoch 00010: saving model to ./checkpoints/
# Epoch 11/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.1193 - accuracy: 0.8968 - dice_coef: 0.8168 - IOU: 0.6904 - specificity: 0.9792 - recall: 0.8118 - precision: 0.9567 - val_loss: 0.5144 - val_accuracy: 0.7752 - val_dice_coef: 0.2934 - val_IOU: 0.1727 - val_specificity: 0.9989 - val_recall: 0.1186 - val_precision: 0.9902
#
# Epoch 00011: saving model to ./checkpoints/
# Epoch 12/200
# 47/47 [==============================] - 16s 341ms/step - loss: 0.1124 - accuracy: 0.8986 - dice_coef: 0.8272 - IOU: 0.7054 - specificity: 0.9792 - recall: 0.8235 - precision: 0.9583 - val_loss: 0.5741 - val_accuracy: 0.7639 - val_dice_coef: 0.2066 - val_IOU: 0.1156 - val_specificity: 0.9997 - val_recall: 0.0578 - val_precision: 0.9963
#
# Epoch 00012: saving model to ./checkpoints/
# Epoch 13/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1077 - accuracy: 0.8997 - dice_coef: 0.8343 - IOU: 0.7157 - specificity: 0.9807 - recall: 0.8213 - precision: 0.9627 - val_loss: 0.4635 - val_accuracy: 0.8110 - val_dice_coef: 0.4863 - val_IOU: 0.3257 - val_specificity: 0.9966 - val_recall: 0.3086 - val_precision: 0.9863
#
# Epoch 00013: saving model to ./checkpoints/
# Epoch 14/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1062 - accuracy: 0.8996 - dice_coef: 0.8377 - IOU: 0.7208 - specificity: 0.9803 - recall: 0.8238 - precision: 0.9613 - val_loss: 0.3868 - val_accuracy: 0.8199 - val_dice_coef: 0.5299 - val_IOU: 0.3662 - val_specificity: 0.9959 - val_recall: 0.3519 - val_precision: 0.9872
#
# Epoch 00014: saving model to ./checkpoints/
# Epoch 15/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1054 - accuracy: 0.8996 - dice_coef: 0.8391 - IOU: 0.7229 - specificity: 0.9810 - recall: 0.8192 - precision: 0.9628 - val_loss: 0.8147 - val_accuracy: 0.7610 - val_dice_coef: 0.1256 - val_IOU: 0.0672 - val_specificity: 0.9998 - val_recall: 0.0443 - val_precision: 0.9974
#
# Epoch 00015: saving model to ./checkpoints/
# Epoch 16/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.1027 - accuracy: 0.9002 - dice_coef: 0.8438 - IOU: 0.7299 - specificity: 0.9805 - recall: 0.8265 - precision: 0.9620 - val_loss: 0.3566 - val_accuracy: 0.8426 - val_dice_coef: 0.6566 - val_IOU: 0.4942 - val_specificity: 0.9902 - val_recall: 0.4971 - val_precision: 0.9753
#
# Epoch 00016: saving model to ./checkpoints/
# Epoch 17/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.1069 - accuracy: 0.8983 - dice_coef: 0.8387 - IOU: 0.7224 - specificity: 0.9803 - recall: 0.8165 - precision: 0.9594 - val_loss: 0.7905 - val_accuracy: 0.7661 - val_dice_coef: 0.1723 - val_IOU: 0.0955 - val_specificity: 0.9984 - val_recall: 0.0771 - val_precision: 0.9710
#
# Epoch 00017: saving model to ./checkpoints/
# Epoch 18/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0995 - accuracy: 0.9008 - dice_coef: 0.8489 - IOU: 0.7375 - specificity: 0.9816 - recall: 0.8251 - precision: 0.9647 - val_loss: 0.8730 - val_accuracy: 0.7570 - val_dice_coef: 0.0867 - val_IOU: 0.0455 - val_specificity: 0.9999 - val_recall: 0.0238 - val_precision: 0.9976
#
# Epoch 00018: saving model to ./checkpoints/
# Epoch 19/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0958 - accuracy: 0.9019 - dice_coef: 0.8542 - IOU: 0.7456 - specificity: 0.9818 - recall: 0.8302 - precision: 0.9660 - val_loss: 0.8196 - val_accuracy: 0.7577 - val_dice_coef: 0.0975 - val_IOU: 0.0514 - val_specificity: 0.9999 - val_recall: 0.0266 - val_precision: 0.9971
#
# Epoch 00019: saving model to ./checkpoints/
# Epoch 20/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0947 - accuracy: 0.9019 - dice_coef: 0.8558 - IOU: 0.7480 - specificity: 0.9823 - recall: 0.8281 - precision: 0.9671 - val_loss: 0.6149 - val_accuracy: 0.7961 - val_dice_coef: 0.3974 - val_IOU: 0.2530 - val_specificity: 0.9976 - val_recall: 0.2291 - val_precision: 0.9873
#
# Epoch 00020: saving model to ./checkpoints/
# Epoch 21/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0930 - accuracy: 0.9023 - dice_coef: 0.8588 - IOU: 0.7525 - specificity: 0.9821 - recall: 0.8320 - precision: 0.9670 - val_loss: 0.6631 - val_accuracy: 0.7958 - val_dice_coef: 0.3919 - val_IOU: 0.2477 - val_specificity: 0.9981 - val_recall: 0.2233 - val_precision: 0.9895
#
# Epoch 00021: saving model to ./checkpoints/
# Epoch 22/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0893 - accuracy: 0.9034 - dice_coef: 0.8637 - IOU: 0.7602 - specificity: 0.9832 - recall: 0.8327 - precision: 0.9702 - val_loss: 1.0559 - val_accuracy: 0.7605 - val_dice_coef: 0.1018 - val_IOU: 0.0540 - val_specificity: 0.9998 - val_recall: 0.0416 - val_precision: 0.9944
#
# Epoch 00022: saving model to ./checkpoints/
# Epoch 23/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0868 - accuracy: 0.9040 - dice_coef: 0.8678 - IOU: 0.7664 - specificity: 0.9831 - recall: 0.8391 - precision: 0.9700 - val_loss: 0.9818 - val_accuracy: 0.7584 - val_dice_coef: 0.0825 - val_IOU: 0.0433 - val_specificity: 0.9998 - val_recall: 0.0308 - val_precision: 0.9954
#
# Epoch 00023: saving model to ./checkpoints/
# Epoch 24/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0870 - accuracy: 0.9039 - dice_coef: 0.8676 - IOU: 0.7662 - specificity: 0.9834 - recall: 0.8354 - precision: 0.9706 - val_loss: 0.6212 - val_accuracy: 0.8112 - val_dice_coef: 0.4843 - val_IOU: 0.3258 - val_specificity: 0.9956 - val_recall: 0.3149 - val_precision: 0.9828
#
# Epoch 00024: saving model to ./checkpoints/
# Epoch 25/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0843 - accuracy: 0.9046 - dice_coef: 0.8717 - IOU: 0.7725 - specificity: 0.9837 - recall: 0.8395 - precision: 0.9716 - val_loss: 0.6139 - val_accuracy: 0.8146 - val_dice_coef: 0.5071 - val_IOU: 0.3465 - val_specificity: 0.9953 - val_recall: 0.3323 - val_precision: 0.9828
#
# Epoch 00025: saving model to ./checkpoints/
# Epoch 26/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0831 - accuracy: 0.9049 - dice_coef: 0.8736 - IOU: 0.7755 - specificity: 0.9840 - recall: 0.8394 - precision: 0.9727 - val_loss: 0.3951 - val_accuracy: 0.8399 - val_dice_coef: 0.6412 - val_IOU: 0.4788 - val_specificity: 0.9934 - val_recall: 0.4705 - val_precision: 0.9820
#
# Epoch 00026: saving model to ./checkpoints/
# Epoch 27/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0818 - accuracy: 0.9052 - dice_coef: 0.8757 - IOU: 0.7790 - specificity: 0.9839 - recall: 0.8421 - precision: 0.9726 - val_loss: 0.4040 - val_accuracy: 0.8449 - val_dice_coef: 0.6664 - val_IOU: 0.5073 - val_specificity: 0.9915 - val_recall: 0.5032 - val_precision: 0.9781
#
# Epoch 00027: saving model to ./checkpoints/
# Epoch 28/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0811 - accuracy: 0.9053 - dice_coef: 0.8768 - IOU: 0.7807 - specificity: 0.9842 - recall: 0.8413 - precision: 0.9732 - val_loss: 0.3085 - val_accuracy: 0.8651 - val_dice_coef: 0.7582 - val_IOU: 0.6149 - val_specificity: 0.9894 - val_recall: 0.6169 - val_precision: 0.9770
#
# Epoch 00028: saving model to ./checkpoints/
# Epoch 29/200
# 47/47 [==============================] - 16s 343ms/step - loss: 0.0783 - accuracy: 0.9062 - dice_coef: 0.8807 - IOU: 0.7868 - specificity: 0.9849 - recall: 0.8437 - precision: 0.9751 - val_loss: 0.1646 - val_accuracy: 0.8838 - val_dice_coef: 0.8172 - val_IOU: 0.6922 - val_specificity: 0.9898 - val_recall: 0.7098 - val_precision: 0.9789
#
# Epoch 00029: saving model to ./checkpoints/
# Epoch 30/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0783 - accuracy: 0.9060 - dice_coef: 0.8813 - IOU: 0.7878 - specificity: 0.9846 - recall: 0.8443 - precision: 0.9742 - val_loss: 0.1583 - val_accuracy: 0.8878 - val_dice_coef: 0.8484 - val_IOU: 0.7380 - val_specificity: 0.9809 - val_recall: 0.7723 - val_precision: 0.9678
#
# Epoch 00030: saving model to ./checkpoints/
# Epoch 31/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0788 - accuracy: 0.9058 - dice_coef: 0.8802 - IOU: 0.7860 - specificity: 0.9843 - recall: 0.8444 - precision: 0.9738 - val_loss: 0.3645 - val_accuracy: 0.8527 - val_dice_coef: 0.7074 - val_IOU: 0.5541 - val_specificity: 0.9914 - val_recall: 0.5427 - val_precision: 0.9799
#
# Epoch 00031: saving model to ./checkpoints/
# Epoch 32/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0982 - accuracy: 0.9003 - dice_coef: 0.8576 - IOU: 0.7512 - specificity: 0.9825 - recall: 0.8183 - precision: 0.9649 - val_loss: 2.8270 - val_accuracy: 0.5189 - val_dice_coef: 0.4905 - val_IOU: 0.3255 - val_specificity: 0.4520 - val_recall: 0.9967 - val_precision: 0.3839
#
# Epoch 00032: saving model to ./checkpoints/
# Epoch 33/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0978 - accuracy: 0.8997 - dice_coef: 0.8556 - IOU: 0.7479 - specificity: 0.9802 - recall: 0.8271 - precision: 0.9604 - val_loss: 0.4293 - val_accuracy: 0.8429 - val_dice_coef: 0.6803 - val_IOU: 0.5199 - val_specificity: 0.9801 - val_recall: 0.5384 - val_precision: 0.9509
#
# Epoch 00033: saving model to ./checkpoints/
# Epoch 34/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0835 - accuracy: 0.9044 - dice_coef: 0.8743 - IOU: 0.7768 - specificity: 0.9833 - recall: 0.8409 - precision: 0.9703 - val_loss: 0.1155 - val_accuracy: 0.8933 - val_dice_coef: 0.8496 - val_IOU: 0.7389 - val_specificity: 0.9880 - val_recall: 0.7651 - val_precision: 0.9808
#
# Epoch 00034: saving model to ./checkpoints/
# Epoch 35/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0781 - accuracy: 0.9059 - dice_coef: 0.8817 - IOU: 0.7885 - specificity: 0.9843 - recall: 0.8455 - precision: 0.9738 - val_loss: 0.3455 - val_accuracy: 0.8494 - val_dice_coef: 0.6829 - val_IOU: 0.5234 - val_specificity: 0.9955 - val_recall: 0.5063 - val_precision: 0.9890
#
# Epoch 00035: saving model to ./checkpoints/
# Epoch 36/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0761 - accuracy: 0.9065 - dice_coef: 0.8845 - IOU: 0.7930 - specificity: 0.9850 - recall: 0.8459 - precision: 0.9754 - val_loss: 0.1649 - val_accuracy: 0.8822 - val_dice_coef: 0.7961 - val_IOU: 0.6622 - val_specificity: 0.9919 - val_recall: 0.6968 - val_precision: 0.9834
#
# Epoch 00036: saving model to ./checkpoints/
# Epoch 37/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0750 - accuracy: 0.9068 - dice_coef: 0.8867 - IOU: 0.7964 - specificity: 0.9847 - recall: 0.8490 - precision: 0.9752 - val_loss: 0.4172 - val_accuracy: 0.8427 - val_dice_coef: 0.6426 - val_IOU: 0.4787 - val_specificity: 0.9956 - val_recall: 0.4701 - val_precision: 0.9872
#
# Epoch 00037: saving model to ./checkpoints/
# Epoch 38/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0729 - accuracy: 0.9074 - dice_coef: 0.8893 - IOU: 0.8007 - specificity: 0.9856 - recall: 0.8481 - precision: 0.9774 - val_loss: 0.4718 - val_accuracy: 0.8405 - val_dice_coef: 0.6334 - val_IOU: 0.4696 - val_specificity: 0.9954 - val_recall: 0.4627 - val_precision: 0.9861
#
# Epoch 00038: saving model to ./checkpoints/
# Epoch 39/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0717 - accuracy: 0.9077 - dice_coef: 0.8914 - IOU: 0.8041 - specificity: 0.9859 - recall: 0.8498 - precision: 0.9778 - val_loss: 0.1364 - val_accuracy: 0.8907 - val_dice_coef: 0.8410 - val_IOU: 0.7264 - val_specificity: 0.9903 - val_recall: 0.7445 - val_precision: 0.9810
#
# Epoch 00039: saving model to ./checkpoints/
# Epoch 40/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0704 - accuracy: 0.9080 - dice_coef: 0.8935 - IOU: 0.8076 - specificity: 0.9859 - recall: 0.8517 - precision: 0.9784 - val_loss: 0.2102 - val_accuracy: 0.8810 - val_dice_coef: 0.8094 - val_IOU: 0.6814 - val_specificity: 0.9898 - val_recall: 0.6993 - val_precision: 0.9786
#
# Epoch 00040: saving model to ./checkpoints/
# Epoch 41/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0703 - accuracy: 0.9080 - dice_coef: 0.8939 - IOU: 0.8082 - specificity: 0.9862 - recall: 0.8502 - precision: 0.9786 - val_loss: 0.1207 - val_accuracy: 0.8940 - val_dice_coef: 0.8628 - val_IOU: 0.7592 - val_specificity: 0.9841 - val_recall: 0.7958 - val_precision: 0.9710
#
# Epoch 00041: saving model to ./checkpoints/
# Epoch 42/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0699 - accuracy: 0.9081 - dice_coef: 0.8947 - IOU: 0.8094 - specificity: 0.9861 - recall: 0.8508 - precision: 0.9786 - val_loss: 0.2923 - val_accuracy: 0.8715 - val_dice_coef: 0.7792 - val_IOU: 0.6414 - val_specificity: 0.9886 - val_recall: 0.6584 - val_precision: 0.9769
#
# Epoch 00042: saving model to ./checkpoints/
# Epoch 43/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0675 - accuracy: 0.9088 - dice_coef: 0.8978 - IOU: 0.8145 - specificity: 0.9868 - recall: 0.8534 - precision: 0.9800 - val_loss: 0.2805 - val_accuracy: 0.8730 - val_dice_coef: 0.7893 - val_IOU: 0.6543 - val_specificity: 0.9906 - val_recall: 0.6546 - val_precision: 0.9819
#
# Epoch 00043: saving model to ./checkpoints/
# Epoch 44/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0667 - accuracy: 0.9090 - dice_coef: 0.8993 - IOU: 0.8171 - specificity: 0.9870 - recall: 0.8535 - precision: 0.9806 - val_loss: 0.2726 - val_accuracy: 0.8679 - val_dice_coef: 0.7591 - val_IOU: 0.6136 - val_specificity: 0.9885 - val_recall: 0.6386 - val_precision: 0.9754
#
# Epoch 00044: saving model to ./checkpoints/
# Epoch 45/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0655 - accuracy: 0.9093 - dice_coef: 0.9011 - IOU: 0.8200 - specificity: 0.9871 - recall: 0.8558 - precision: 0.9810 - val_loss: 0.1160 - val_accuracy: 0.8959 - val_dice_coef: 0.8692 - val_IOU: 0.7691 - val_specificity: 0.9863 - val_recall: 0.7957 - val_precision: 0.9769
#
# Epoch 00045: saving model to ./checkpoints/
# Epoch 46/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0649 - accuracy: 0.9095 - dice_coef: 0.9022 - IOU: 0.8219 - specificity: 0.9874 - recall: 0.8551 - precision: 0.9816 - val_loss: 0.1658 - val_accuracy: 0.8840 - val_dice_coef: 0.8203 - val_IOU: 0.6965 - val_specificity: 0.9865 - val_recall: 0.7309 - val_precision: 0.9714
#
# Epoch 00046: saving model to ./checkpoints/
# Epoch 47/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0645 - accuracy: 0.9095 - dice_coef: 0.9029 - IOU: 0.8230 - specificity: 0.9875 - recall: 0.8546 - precision: 0.9817 - val_loss: 0.1869 - val_accuracy: 0.8836 - val_dice_coef: 0.8233 - val_IOU: 0.7009 - val_specificity: 0.9844 - val_recall: 0.7404 - val_precision: 0.9710
#
# Epoch 00047: saving model to ./checkpoints/
# Epoch 48/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0640 - accuracy: 0.9096 - dice_coef: 0.9038 - IOU: 0.8245 - specificity: 0.9876 - recall: 0.8560 - precision: 0.9818 - val_loss: 0.2600 - val_accuracy: 0.8752 - val_dice_coef: 0.7944 - val_IOU: 0.6611 - val_specificity: 0.9908 - val_recall: 0.6654 - val_precision: 0.9826
#
# Epoch 00048: saving model to ./checkpoints/
# Epoch 49/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0625 - accuracy: 0.9101 - dice_coef: 0.9060 - IOU: 0.8281 - specificity: 0.9879 - recall: 0.8573 - precision: 0.9828 - val_loss: 0.4960 - val_accuracy: 0.8350 - val_dice_coef: 0.6119 - val_IOU: 0.4458 - val_specificity: 0.9948 - val_recall: 0.4333 - val_precision: 0.9847
#
# Epoch 00049: saving model to ./checkpoints/
# Epoch 50/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0628 - accuracy: 0.9100 - dice_coef: 0.9053 - IOU: 0.8271 - specificity: 0.9881 - recall: 0.8551 - precision: 0.9829 - val_loss: 0.2991 - val_accuracy: 0.8689 - val_dice_coef: 0.7721 - val_IOU: 0.6311 - val_specificity: 0.9859 - val_recall: 0.6593 - val_precision: 0.9716
#
# Epoch 00050: saving model to ./checkpoints/
# Epoch 51/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0618 - accuracy: 0.9102 - dice_coef: 0.9072 - IOU: 0.8302 - specificity: 0.9879 - recall: 0.8586 - precision: 0.9829 - val_loss: 0.2254 - val_accuracy: 0.8790 - val_dice_coef: 0.8159 - val_IOU: 0.6909 - val_specificity: 0.9856 - val_recall: 0.7109 - val_precision: 0.9729
#
# Epoch 00051: saving model to ./checkpoints/
# Epoch 52/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0605 - accuracy: 0.9106 - dice_coef: 0.9092 - IOU: 0.8335 - specificity: 0.9884 - recall: 0.8585 - precision: 0.9837 - val_loss: 0.2052 - val_accuracy: 0.8805 - val_dice_coef: 0.8146 - val_IOU: 0.6889 - val_specificity: 0.9868 - val_recall: 0.7112 - val_precision: 0.9745
#
# Epoch 00052: saving model to ./checkpoints/
# Epoch 53/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0596 - accuracy: 0.9108 - dice_coef: 0.9104 - IOU: 0.8356 - specificity: 0.9885 - recall: 0.8597 - precision: 0.9842 - val_loss: 0.4178 - val_accuracy: 0.8561 - val_dice_coef: 0.7211 - val_IOU: 0.5670 - val_specificity: 0.9900 - val_recall: 0.5672 - val_precision: 0.9761
#
# Epoch 00053: saving model to ./checkpoints/
# Epoch 54/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0595 - accuracy: 0.9108 - dice_coef: 0.9106 - IOU: 0.8359 - specificity: 0.9887 - recall: 0.8583 - precision: 0.9844 - val_loss: 0.2170 - val_accuracy: 0.8832 - val_dice_coef: 0.8255 - val_IOU: 0.7040 - val_specificity: 0.9887 - val_recall: 0.7143 - val_precision: 0.9788
#
# Epoch 00054: saving model to ./checkpoints/
# Epoch 55/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0586 - accuracy: 0.9110 - dice_coef: 0.9118 - IOU: 0.8380 - specificity: 0.9888 - recall: 0.8593 - precision: 0.9849 - val_loss: 0.3263 - val_accuracy: 0.8694 - val_dice_coef: 0.7686 - val_IOU: 0.6262 - val_specificity: 0.9888 - val_recall: 0.6393 - val_precision: 0.9774
#
# Epoch 00055: saving model to ./checkpoints/
# Epoch 56/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0578 - accuracy: 0.9112 - dice_coef: 0.9132 - IOU: 0.8403 - specificity: 0.9891 - recall: 0.8597 - precision: 0.9853 - val_loss: 0.4111 - val_accuracy: 0.8574 - val_dice_coef: 0.7259 - val_IOU: 0.5733 - val_specificity: 0.9910 - val_recall: 0.5714 - val_precision: 0.9799
#
# Epoch 00056: saving model to ./checkpoints/
# Epoch 57/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0576 - accuracy: 0.9112 - dice_coef: 0.9139 - IOU: 0.8415 - specificity: 0.9892 - recall: 0.8592 - precision: 0.9855 - val_loss: 0.1093 - val_accuracy: 0.8989 - val_dice_coef: 0.8849 - val_IOU: 0.7940 - val_specificity: 0.9832 - val_recall: 0.8272 - val_precision: 0.9737
#
# Epoch 00057: saving model to ./checkpoints/
# Epoch 58/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0566 - accuracy: 0.9115 - dice_coef: 0.9153 - IOU: 0.8438 - specificity: 0.9895 - recall: 0.8604 - precision: 0.9860 - val_loss: 0.2022 - val_accuracy: 0.8849 - val_dice_coef: 0.8306 - val_IOU: 0.7117 - val_specificity: 0.9915 - val_recall: 0.7094 - val_precision: 0.9858
#
# Epoch 00058: saving model to ./checkpoints/
# Epoch 59/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0559 - accuracy: 0.9117 - dice_coef: 0.9162 - IOU: 0.8453 - specificity: 0.9897 - recall: 0.8605 - precision: 0.9864 - val_loss: 0.2903 - val_accuracy: 0.8727 - val_dice_coef: 0.7856 - val_IOU: 0.6490 - val_specificity: 0.9894 - val_recall: 0.6556 - val_precision: 0.9796
#
# Epoch 00059: saving model to ./checkpoints/
# Epoch 60/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0557 - accuracy: 0.9117 - dice_coef: 0.9166 - IOU: 0.8460 - specificity: 0.9899 - recall: 0.8595 - precision: 0.9867 - val_loss: 0.1759 - val_accuracy: 0.8878 - val_dice_coef: 0.8424 - val_IOU: 0.7289 - val_specificity: 0.9840 - val_recall: 0.7662 - val_precision: 0.9715
#
# Epoch 00060: saving model to ./checkpoints/
# Epoch 61/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0551 - accuracy: 0.9118 - dice_coef: 0.9176 - IOU: 0.8477 - specificity: 0.9897 - recall: 0.8611 - precision: 0.9867 - val_loss: 0.6663 - val_accuracy: 0.8293 - val_dice_coef: 0.5846 - val_IOU: 0.4205 - val_specificity: 0.9926 - val_recall: 0.4186 - val_precision: 0.9754
#
# Epoch 00061: saving model to ./checkpoints/
# Epoch 62/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0543 - accuracy: 0.9121 - dice_coef: 0.9187 - IOU: 0.8496 - specificity: 0.9900 - recall: 0.8621 - precision: 0.9871 - val_loss: 0.2033 - val_accuracy: 0.8823 - val_dice_coef: 0.8213 - val_IOU: 0.6991 - val_specificity: 0.9869 - val_recall: 0.7185 - val_precision: 0.9734
#
# Epoch 00062: saving model to ./checkpoints/
# Epoch 63/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0546 - accuracy: 0.9120 - dice_coef: 0.9183 - IOU: 0.8489 - specificity: 0.9901 - recall: 0.8600 - precision: 0.9872 - val_loss: 0.1989 - val_accuracy: 0.8872 - val_dice_coef: 0.8357 - val_IOU: 0.7196 - val_specificity: 0.9852 - val_recall: 0.7560 - val_precision: 0.9725
#
# Epoch 00063: saving model to ./checkpoints/
# Epoch 64/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0549 - accuracy: 0.9118 - dice_coef: 0.9178 - IOU: 0.8480 - specificity: 0.9898 - recall: 0.8614 - precision: 0.9865 - val_loss: 0.1017 - val_accuracy: 0.9022 - val_dice_coef: 0.9037 - val_IOU: 0.8246 - val_specificity: 0.9855 - val_recall: 0.8333 - val_precision: 0.9796
#
# Epoch 00064: saving model to ./checkpoints/
# Epoch 65/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0559 - accuracy: 0.9116 - dice_coef: 0.9166 - IOU: 0.8460 - specificity: 0.9899 - recall: 0.8577 - precision: 0.9865 - val_loss: 0.4245 - val_accuracy: 0.8676 - val_dice_coef: 0.7727 - val_IOU: 0.6314 - val_specificity: 0.9905 - val_recall: 0.6309 - val_precision: 0.9813
#
# Epoch 00065: saving model to ./checkpoints/
# Epoch 66/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0526 - accuracy: 0.9125 - dice_coef: 0.9214 - IOU: 0.8543 - specificity: 0.9905 - recall: 0.8629 - precision: 0.9880 - val_loss: 0.2273 - val_accuracy: 0.8845 - val_dice_coef: 0.8363 - val_IOU: 0.7202 - val_specificity: 0.9904 - val_recall: 0.7170 - val_precision: 0.9835
#
# Epoch 00066: saving model to ./checkpoints/
# Epoch 67/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0517 - accuracy: 0.9127 - dice_coef: 0.9227 - IOU: 0.8566 - specificity: 0.9908 - recall: 0.8624 - precision: 0.9885 - val_loss: 0.8956 - val_accuracy: 0.8079 - val_dice_coef: 0.4732 - val_IOU: 0.3133 - val_specificity: 0.9945 - val_recall: 0.2997 - val_precision: 0.9753
#
# Epoch 00067: saving model to ./checkpoints/
# Epoch 68/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0522 - accuracy: 0.9125 - dice_coef: 0.9223 - IOU: 0.8558 - specificity: 0.9907 - recall: 0.8616 - precision: 0.9883 - val_loss: 0.8249 - val_accuracy: 0.8275 - val_dice_coef: 0.5875 - val_IOU: 0.4222 - val_specificity: 0.9921 - val_recall: 0.4121 - val_precision: 0.9759
#
# Epoch 00068: saving model to ./checkpoints/
# Epoch 69/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0526 - accuracy: 0.9124 - dice_coef: 0.9218 - IOU: 0.8550 - specificity: 0.9906 - recall: 0.8611 - precision: 0.9879 - val_loss: 0.1499 - val_accuracy: 0.8981 - val_dice_coef: 0.8917 - val_IOU: 0.8054 - val_specificity: 0.9837 - val_recall: 0.8217 - val_precision: 0.9762
#
# Epoch 00069: saving model to ./checkpoints/
# Epoch 70/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0509 - accuracy: 0.9128 - dice_coef: 0.9241 - IOU: 0.8590 - specificity: 0.9912 - recall: 0.8619 - precision: 0.9891 - val_loss: 0.2471 - val_accuracy: 0.8821 - val_dice_coef: 0.8250 - val_IOU: 0.7046 - val_specificity: 0.9851 - val_recall: 0.7307 - val_precision: 0.9718
#
# Epoch 00070: saving model to ./checkpoints/
# Epoch 71/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0507 - accuracy: 0.9128 - dice_coef: 0.9244 - IOU: 0.8595 - specificity: 0.9911 - recall: 0.8620 - precision: 0.9890 - val_loss: 0.3592 - val_accuracy: 0.8711 - val_dice_coef: 0.7886 - val_IOU: 0.6541 - val_specificity: 0.9852 - val_recall: 0.6706 - val_precision: 0.9686
#
# Epoch 00071: saving model to ./checkpoints/
# Epoch 72/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0511 - accuracy: 0.9127 - dice_coef: 0.9239 - IOU: 0.8586 - specificity: 0.9911 - recall: 0.8612 - precision: 0.9888 - val_loss: 0.1180 - val_accuracy: 0.9000 - val_dice_coef: 0.8922 - val_IOU: 0.8058 - val_specificity: 0.9866 - val_recall: 0.8179 - val_precision: 0.9794
#
# Epoch 00072: saving model to ./checkpoints/
# Epoch 73/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0507 - accuracy: 0.9128 - dice_coef: 0.9247 - IOU: 0.8600 - specificity: 0.9911 - recall: 0.8622 - precision: 0.9889 - val_loss: 0.0968 - val_accuracy: 0.9028 - val_dice_coef: 0.9023 - val_IOU: 0.8222 - val_specificity: 0.9861 - val_recall: 0.8339 - val_precision: 0.9790
#
# Epoch 00073: saving model to ./checkpoints/
# Epoch 74/200
# 47/47 [==============================] - 16s 337ms/step - loss: 0.0491 - accuracy: 0.9132 - dice_coef: 0.9268 - IOU: 0.8636 - specificity: 0.9916 - recall: 0.8626 - precision: 0.9898 - val_loss: 0.2174 - val_accuracy: 0.8881 - val_dice_coef: 0.8473 - val_IOU: 0.7363 - val_specificity: 0.9926 - val_recall: 0.7209 - val_precision: 0.9882
#
# Epoch 00074: saving model to ./checkpoints/
# Epoch 75/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0487 - accuracy: 0.9133 - dice_coef: 0.9275 - IOU: 0.8648 - specificity: 0.9917 - recall: 0.8628 - precision: 0.9901 - val_loss: 0.4338 - val_accuracy: 0.8645 - val_dice_coef: 0.7602 - val_IOU: 0.6162 - val_specificity: 0.9896 - val_recall: 0.6104 - val_precision: 0.9778
#
# Epoch 00075: saving model to ./checkpoints/
# Epoch 76/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0485 - accuracy: 0.9134 - dice_coef: 0.9279 - IOU: 0.8655 - specificity: 0.9918 - recall: 0.8627 - precision: 0.9903 - val_loss: 0.7424 - val_accuracy: 0.8336 - val_dice_coef: 0.6157 - val_IOU: 0.4508 - val_specificity: 0.9926 - val_recall: 0.4381 - val_precision: 0.9785
#
# Epoch 00076: saving model to ./checkpoints/
# Epoch 77/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0489 - accuracy: 0.9132 - dice_coef: 0.9273 - IOU: 0.8645 - specificity: 0.9918 - recall: 0.8614 - precision: 0.9901 - val_loss: 0.9450 - val_accuracy: 0.8104 - val_dice_coef: 0.4880 - val_IOU: 0.3258 - val_specificity: 0.9930 - val_recall: 0.3197 - val_precision: 0.9681
#
# Epoch 00077: saving model to ./checkpoints/
# Epoch 78/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0482 - accuracy: 0.9134 - dice_coef: 0.9285 - IOU: 0.8665 - specificity: 0.9919 - recall: 0.8629 - precision: 0.9902 - val_loss: 1.0189 - val_accuracy: 0.8054 - val_dice_coef: 0.4583 - val_IOU: 0.3001 - val_specificity: 0.9940 - val_recall: 0.2897 - val_precision: 0.9709
#
# Epoch 00078: saving model to ./checkpoints/
# Epoch 79/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0476 - accuracy: 0.9136 - dice_coef: 0.9292 - IOU: 0.8677 - specificity: 0.9921 - recall: 0.8627 - precision: 0.9907 - val_loss: 0.2995 - val_accuracy: 0.8764 - val_dice_coef: 0.8066 - val_IOU: 0.6795 - val_specificity: 0.9910 - val_recall: 0.6709 - val_precision: 0.9832
#
# Epoch 00079: saving model to ./checkpoints/
# Epoch 80/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0470 - accuracy: 0.9137 - dice_coef: 0.9301 - IOU: 0.8693 - specificity: 0.9924 - recall: 0.8622 - precision: 0.9911 - val_loss: 0.1010 - val_accuracy: 0.9017 - val_dice_coef: 0.8940 - val_IOU: 0.8086 - val_specificity: 0.9865 - val_recall: 0.8275 - val_precision: 0.9782
#
# Epoch 00080: saving model to ./checkpoints/
# Epoch 81/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0475 - accuracy: 0.9136 - dice_coef: 0.9295 - IOU: 0.8682 - specificity: 0.9922 - recall: 0.8620 - precision: 0.9907 - val_loss: 0.1067 - val_accuracy: 0.9021 - val_dice_coef: 0.9020 - val_IOU: 0.8217 - val_specificity: 0.9870 - val_recall: 0.8260 - val_precision: 0.9798
#
# Epoch 00081: saving model to ./checkpoints/
# Epoch 82/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0475 - accuracy: 0.9135 - dice_coef: 0.9295 - IOU: 0.8683 - specificity: 0.9922 - recall: 0.8608 - precision: 0.9908 - val_loss: 0.0953 - val_accuracy: 0.9031 - val_dice_coef: 0.9020 - val_IOU: 0.8217 - val_specificity: 0.9861 - val_recall: 0.8358 - val_precision: 0.9785
#
# Epoch 00082: saving model to ./checkpoints/
# Epoch 83/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0477 - accuracy: 0.9135 - dice_coef: 0.9292 - IOU: 0.8677 - specificity: 0.9921 - recall: 0.8614 - precision: 0.9906 - val_loss: 0.2138 - val_accuracy: 0.8861 - val_dice_coef: 0.8507 - val_IOU: 0.7421 - val_specificity: 0.9783 - val_recall: 0.7758 - val_precision: 0.9576
#
# Epoch 00083: saving model to ./checkpoints/
# Epoch 84/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0465 - accuracy: 0.9138 - dice_coef: 0.9310 - IOU: 0.8709 - specificity: 0.9925 - recall: 0.8627 - precision: 0.9913 - val_loss: 0.1186 - val_accuracy: 0.9002 - val_dice_coef: 0.8964 - val_IOU: 0.8126 - val_specificity: 0.9847 - val_recall: 0.8257 - val_precision: 0.9753
#
# Epoch 00084: saving model to ./checkpoints/
# Epoch 85/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0458 - accuracy: 0.9139 - dice_coef: 0.9319 - IOU: 0.8724 - specificity: 0.9927 - recall: 0.8621 - precision: 0.9916 - val_loss: 0.0767 - val_accuracy: 0.9056 - val_dice_coef: 0.9119 - val_IOU: 0.8382 - val_specificity: 0.9874 - val_recall: 0.8437 - val_precision: 0.9800
#
# Epoch 00085: saving model to ./checkpoints/
# Epoch 86/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0462 - accuracy: 0.9138 - dice_coef: 0.9314 - IOU: 0.8717 - specificity: 0.9926 - recall: 0.8625 - precision: 0.9914 - val_loss: 0.0913 - val_accuracy: 0.9041 - val_dice_coef: 0.9098 - val_IOU: 0.8347 - val_specificity: 0.9867 - val_recall: 0.8383 - val_precision: 0.9801
#
# Epoch 00086: saving model to ./checkpoints/
# Epoch 87/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0458 - accuracy: 0.9139 - dice_coef: 0.9321 - IOU: 0.8728 - specificity: 0.9927 - recall: 0.8624 - precision: 0.9916 - val_loss: 0.0852 - val_accuracy: 0.9049 - val_dice_coef: 0.9111 - val_IOU: 0.8370 - val_specificity: 0.9884 - val_recall: 0.8352 - val_precision: 0.9829
#
# Epoch 00087: saving model to ./checkpoints/
# Epoch 88/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0448 - accuracy: 0.9142 - dice_coef: 0.9336 - IOU: 0.8754 - specificity: 0.9929 - recall: 0.8637 - precision: 0.9920 - val_loss: 0.0823 - val_accuracy: 0.9049 - val_dice_coef: 0.9096 - val_IOU: 0.8343 - val_specificity: 0.9891 - val_recall: 0.8318 - val_precision: 0.9834
#
# Epoch 00088: saving model to ./checkpoints/
# Epoch 89/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0448 - accuracy: 0.9141 - dice_coef: 0.9335 - IOU: 0.8753 - specificity: 0.9930 - recall: 0.8627 - precision: 0.9920 - val_loss: 0.3659 - val_accuracy: 0.8701 - val_dice_coef: 0.7813 - val_IOU: 0.6435 - val_specificity: 0.9909 - val_recall: 0.6348 - val_precision: 0.9813
#
# Epoch 00089: saving model to ./checkpoints/
# Epoch 90/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0448 - accuracy: 0.9141 - dice_coef: 0.9336 - IOU: 0.8754 - specificity: 0.9930 - recall: 0.8629 - precision: 0.9921 - val_loss: 0.2147 - val_accuracy: 0.8868 - val_dice_coef: 0.8442 - val_IOU: 0.7314 - val_specificity: 0.9912 - val_recall: 0.7165 - val_precision: 0.9849
#
# Epoch 00090: saving model to ./checkpoints/
# Epoch 91/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0442 - accuracy: 0.9143 - dice_coef: 0.9345 - IOU: 0.8770 - specificity: 0.9932 - recall: 0.8630 - precision: 0.9922 - val_loss: 0.3178 - val_accuracy: 0.8755 - val_dice_coef: 0.8033 - val_IOU: 0.6736 - val_specificity: 0.9914 - val_recall: 0.6552 - val_precision: 0.9831
#
# Epoch 00091: saving model to ./checkpoints/
# Epoch 92/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0447 - accuracy: 0.9142 - dice_coef: 0.9339 - IOU: 0.8761 - specificity: 0.9932 - recall: 0.8615 - precision: 0.9923 - val_loss: 0.0938 - val_accuracy: 0.9037 - val_dice_coef: 0.9102 - val_IOU: 0.8353 - val_specificity: 0.9858 - val_recall: 0.8395 - val_precision: 0.9793
#
# Epoch 00092: saving model to ./checkpoints/
# Epoch 93/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0442 - accuracy: 0.9142 - dice_coef: 0.9344 - IOU: 0.8768 - specificity: 0.9932 - recall: 0.8621 - precision: 0.9923 - val_loss: 0.1121 - val_accuracy: 0.9003 - val_dice_coef: 0.8927 - val_IOU: 0.8065 - val_specificity: 0.9885 - val_recall: 0.8047 - val_precision: 0.9813
#
# Epoch 00093: saving model to ./checkpoints/
# Epoch 94/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0438 - accuracy: 0.9144 - dice_coef: 0.9351 - IOU: 0.8781 - specificity: 0.9934 - recall: 0.8626 - precision: 0.9926 - val_loss: 0.1107 - val_accuracy: 0.9012 - val_dice_coef: 0.8985 - val_IOU: 0.8161 - val_specificity: 0.9919 - val_recall: 0.7935 - val_precision: 0.9878
#
# Epoch 00094: saving model to ./checkpoints/
# Epoch 95/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0436 - accuracy: 0.9144 - dice_coef: 0.9355 - IOU: 0.8788 - specificity: 0.9934 - recall: 0.8627 - precision: 0.9927 - val_loss: 0.0761 - val_accuracy: 0.9059 - val_dice_coef: 0.9140 - val_IOU: 0.8418 - val_specificity: 0.9914 - val_recall: 0.8230 - val_precision: 0.9871
#
# Epoch 00095: saving model to ./checkpoints/
# Epoch 96/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0437 - accuracy: 0.9143 - dice_coef: 0.9354 - IOU: 0.8786 - specificity: 0.9934 - recall: 0.8625 - precision: 0.9925 - val_loss: 0.0860 - val_accuracy: 0.9059 - val_dice_coef: 0.9203 - val_IOU: 0.8525 - val_specificity: 0.9885 - val_recall: 0.8386 - val_precision: 0.9836
#
# Epoch 00096: saving model to ./checkpoints/
# Epoch 97/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0435 - accuracy: 0.9144 - dice_coef: 0.9357 - IOU: 0.8791 - specificity: 0.9935 - recall: 0.8624 - precision: 0.9927 - val_loss: 0.0809 - val_accuracy: 0.9056 - val_dice_coef: 0.9154 - val_IOU: 0.8441 - val_specificity: 0.9882 - val_recall: 0.8379 - val_precision: 0.9830
#
# Epoch 00097: saving model to ./checkpoints/
# Epoch 98/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0434 - accuracy: 0.9144 - dice_coef: 0.9358 - IOU: 0.8793 - specificity: 0.9935 - recall: 0.8622 - precision: 0.9928 - val_loss: 0.0955 - val_accuracy: 0.9045 - val_dice_coef: 0.9088 - val_IOU: 0.8330 - val_specificity: 0.9915 - val_recall: 0.8168 - val_precision: 0.9882
#
# Epoch 00098: saving model to ./checkpoints/
# Epoch 99/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0431 - accuracy: 0.9145 - dice_coef: 0.9363 - IOU: 0.8802 - specificity: 0.9935 - recall: 0.8629 - precision: 0.9927 - val_loss: 0.0998 - val_accuracy: 0.9027 - val_dice_coef: 0.9051 - val_IOU: 0.8268 - val_specificity: 0.9883 - val_recall: 0.8201 - val_precision: 0.9823
#
# Epoch 00099: saving model to ./checkpoints/
# Epoch 100/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0427 - accuracy: 0.9146 - dice_coef: 0.9367 - IOU: 0.8810 - specificity: 0.9937 - recall: 0.8626 - precision: 0.9930 - val_loss: 0.0827 - val_accuracy: 0.9058 - val_dice_coef: 0.9155 - val_IOU: 0.8443 - val_specificity: 0.9898 - val_recall: 0.8329 - val_precision: 0.9853
#
# Epoch 00100: saving model to ./checkpoints/
# Epoch 101/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0434 - accuracy: 0.9144 - dice_coef: 0.9360 - IOU: 0.8798 - specificity: 0.9936 - recall: 0.8614 - precision: 0.9928 - val_loss: 0.0975 - val_accuracy: 0.9053 - val_dice_coef: 0.9162 - val_IOU: 0.8455 - val_specificity: 0.9875 - val_recall: 0.8428 - val_precision: 0.9824
#
# Epoch 00101: saving model to ./checkpoints/
# Epoch 102/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0441 - accuracy: 0.9142 - dice_coef: 0.9350 - IOU: 0.8780 - specificity: 0.9934 - recall: 0.8607 - precision: 0.9923 - val_loss: 0.0762 - val_accuracy: 0.9073 - val_dice_coef: 0.9267 - val_IOU: 0.8635 - val_specificity: 0.9855 - val_recall: 0.8640 - val_precision: 0.9807
#
# Epoch 00102: saving model to ./checkpoints/
# Epoch 103/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0437 - accuracy: 0.9143 - dice_coef: 0.9355 - IOU: 0.8789 - specificity: 0.9935 - recall: 0.8618 - precision: 0.9926 - val_loss: 0.1138 - val_accuracy: 0.9025 - val_dice_coef: 0.9075 - val_IOU: 0.8308 - val_specificity: 0.9845 - val_recall: 0.8379 - val_precision: 0.9761
#
# Epoch 00103: saving model to ./checkpoints/
# Epoch 104/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0445 - accuracy: 0.9141 - dice_coef: 0.9344 - IOU: 0.8769 - specificity: 0.9931 - recall: 0.8617 - precision: 0.9919 - val_loss: 0.1175 - val_accuracy: 0.9028 - val_dice_coef: 0.9092 - val_IOU: 0.8337 - val_specificity: 0.9888 - val_recall: 0.8170 - val_precision: 0.9844
#
# Epoch 00104: saving model to ./checkpoints/
# Epoch 105/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0456 - accuracy: 0.9138 - dice_coef: 0.9326 - IOU: 0.8738 - specificity: 0.9929 - recall: 0.8609 - precision: 0.9914 - val_loss: 0.0790 - val_accuracy: 0.9068 - val_dice_coef: 0.9234 - val_IOU: 0.8578 - val_specificity: 0.9863 - val_recall: 0.8596 - val_precision: 0.9820
#
# Epoch 00105: saving model to ./checkpoints/
# Epoch 106/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0428 - accuracy: 0.9145 - dice_coef: 0.9368 - IOU: 0.8810 - specificity: 0.9937 - recall: 0.8632 - precision: 0.9929 - val_loss: 0.0725 - val_accuracy: 0.9065 - val_dice_coef: 0.9177 - val_IOU: 0.8479 - val_specificity: 0.9887 - val_recall: 0.8425 - val_precision: 0.9835
#
# Epoch 00106: saving model to ./checkpoints/
# Epoch 107/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0421 - accuracy: 0.9147 - dice_coef: 0.9380 - IOU: 0.8832 - specificity: 0.9938 - recall: 0.8633 - precision: 0.9933 - val_loss: 0.0717 - val_accuracy: 0.9068 - val_dice_coef: 0.9167 - val_IOU: 0.8462 - val_specificity: 0.9910 - val_recall: 0.8319 - val_precision: 0.9865
#
# Epoch 00107: saving model to ./checkpoints/
# Epoch 108/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0423 - accuracy: 0.9146 - dice_coef: 0.9377 - IOU: 0.8827 - specificity: 0.9939 - recall: 0.8621 - precision: 0.9933 - val_loss: 0.0728 - val_accuracy: 0.9064 - val_dice_coef: 0.9152 - val_IOU: 0.8438 - val_specificity: 0.9890 - val_recall: 0.8415 - val_precision: 0.9836
#
# Epoch 00108: saving model to ./checkpoints/
# Epoch 109/200
# 47/47 [==============================] - 16s 341ms/step - loss: 0.0416 - accuracy: 0.9148 - dice_coef: 0.9384 - IOU: 0.8840 - specificity: 0.9941 - recall: 0.8626 - precision: 0.9935 - val_loss: 0.1548 - val_accuracy: 0.8966 - val_dice_coef: 0.8822 - val_IOU: 0.7896 - val_specificity: 0.9909 - val_recall: 0.7682 - val_precision: 0.9849
#
# Epoch 00109: saving model to ./checkpoints/
# Epoch 110/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0423 - accuracy: 0.9146 - dice_coef: 0.9377 - IOU: 0.8826 - specificity: 0.9939 - recall: 0.8618 - precision: 0.9932 - val_loss: 0.1329 - val_accuracy: 0.9012 - val_dice_coef: 0.9002 - val_IOU: 0.8189 - val_specificity: 0.9896 - val_recall: 0.8043 - val_precision: 0.9847
#
# Epoch 00110: saving model to ./checkpoints/
# Epoch 111/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0416 - accuracy: 0.9148 - dice_coef: 0.9387 - IOU: 0.8845 - specificity: 0.9942 - recall: 0.8617 - precision: 0.9937 - val_loss: 0.0749 - val_accuracy: 0.9072 - val_dice_coef: 0.9221 - val_IOU: 0.8555 - val_specificity: 0.9895 - val_recall: 0.8444 - val_precision: 0.9851
#
# Epoch 00111: saving model to ./checkpoints/
# Epoch 112/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0414 - accuracy: 0.9148 - dice_coef: 0.9388 - IOU: 0.8847 - specificity: 0.9943 - recall: 0.8620 - precision: 0.9938 - val_loss: 0.0798 - val_accuracy: 0.9057 - val_dice_coef: 0.9150 - val_IOU: 0.8434 - val_specificity: 0.9914 - val_recall: 0.8236 - val_precision: 0.9875
#
# Epoch 00112: saving model to ./checkpoints/
# Epoch 113/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0411 - accuracy: 0.9149 - dice_coef: 0.9394 - IOU: 0.8857 - specificity: 0.9943 - recall: 0.8622 - precision: 0.9938 - val_loss: 0.1252 - val_accuracy: 0.8997 - val_dice_coef: 0.8929 - val_IOU: 0.8071 - val_specificity: 0.9900 - val_recall: 0.7970 - val_precision: 0.9843
#
# Epoch 00113: saving model to ./checkpoints/
# Epoch 114/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0409 - accuracy: 0.9149 - dice_coef: 0.9396 - IOU: 0.8861 - specificity: 0.9942 - recall: 0.8623 - precision: 0.9939 - val_loss: 0.0880 - val_accuracy: 0.9046 - val_dice_coef: 0.9109 - val_IOU: 0.8365 - val_specificity: 0.9893 - val_recall: 0.8281 - val_precision: 0.9843
#
# Epoch 00114: saving model to ./checkpoints/
# Epoch 115/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0416 - accuracy: 0.9148 - dice_coef: 0.9386 - IOU: 0.8842 - specificity: 0.9942 - recall: 0.8618 - precision: 0.9937 - val_loss: 0.1450 - val_accuracy: 0.8990 - val_dice_coef: 0.8922 - val_IOU: 0.8059 - val_specificity: 0.9886 - val_recall: 0.7968 - val_precision: 0.9823
#
# Epoch 00115: saving model to ./checkpoints/
# Epoch 116/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0407 - accuracy: 0.9150 - dice_coef: 0.9399 - IOU: 0.8867 - specificity: 0.9943 - recall: 0.8630 - precision: 0.9939 - val_loss: 0.0883 - val_accuracy: 0.9051 - val_dice_coef: 0.9146 - val_IOU: 0.8428 - val_specificity: 0.9900 - val_recall: 0.8278 - val_precision: 0.9853
#
# Epoch 00116: saving model to ./checkpoints/
# Epoch 117/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0405 - accuracy: 0.9150 - dice_coef: 0.9403 - IOU: 0.8874 - specificity: 0.9945 - recall: 0.8617 - precision: 0.9942 - val_loss: 0.0790 - val_accuracy: 0.9060 - val_dice_coef: 0.9158 - val_IOU: 0.8448 - val_specificity: 0.9920 - val_recall: 0.8227 - val_precision: 0.9886
#
# Epoch 00117: saving model to ./checkpoints/
# Epoch 118/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0404 - accuracy: 0.9150 - dice_coef: 0.9403 - IOU: 0.8874 - specificity: 0.9944 - recall: 0.8635 - precision: 0.9941 - val_loss: 0.1152 - val_accuracy: 0.9015 - val_dice_coef: 0.9030 - val_IOU: 0.8235 - val_specificity: 0.9908 - val_recall: 0.7994 - val_precision: 0.9857
#
# Epoch 00118: saving model to ./checkpoints/
# Epoch 119/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0405 - accuracy: 0.9150 - dice_coef: 0.9404 - IOU: 0.8875 - specificity: 0.9945 - recall: 0.8622 - precision: 0.9943 - val_loss: 0.0891 - val_accuracy: 0.9059 - val_dice_coef: 0.9187 - val_IOU: 0.8499 - val_specificity: 0.9889 - val_recall: 0.8404 - val_precision: 0.9838
#
# Epoch 00119: saving model to ./checkpoints/
# Epoch 120/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0403 - accuracy: 0.9150 - dice_coef: 0.9407 - IOU: 0.8880 - specificity: 0.9946 - recall: 0.8623 - precision: 0.9942 - val_loss: 0.0734 - val_accuracy: 0.9079 - val_dice_coef: 0.9280 - val_IOU: 0.8658 - val_specificity: 0.9905 - val_recall: 0.8412 - val_precision: 0.9867
#
# Epoch 00120: saving model to ./checkpoints/
# Epoch 121/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0403 - accuracy: 0.9150 - dice_coef: 0.9408 - IOU: 0.8882 - specificity: 0.9946 - recall: 0.8621 - precision: 0.9942 - val_loss: 0.0851 - val_accuracy: 0.9063 - val_dice_coef: 0.9213 - val_IOU: 0.8542 - val_specificity: 0.9889 - val_recall: 0.8403 - val_precision: 0.9844
#
# Epoch 00121: saving model to ./checkpoints/
# Epoch 122/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0400 - accuracy: 0.9151 - dice_coef: 0.9411 - IOU: 0.8888 - specificity: 0.9946 - recall: 0.8625 - precision: 0.9943 - val_loss: 0.0703 - val_accuracy: 0.9077 - val_dice_coef: 0.9251 - val_IOU: 0.8607 - val_specificity: 0.9904 - val_recall: 0.8424 - val_precision: 0.9865
#
# Epoch 00122: saving model to ./checkpoints/
# Epoch 123/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0398 - accuracy: 0.9152 - dice_coef: 0.9416 - IOU: 0.8896 - specificity: 0.9948 - recall: 0.8619 - precision: 0.9945 - val_loss: 0.0710 - val_accuracy: 0.9073 - val_dice_coef: 0.9203 - val_IOU: 0.8524 - val_specificity: 0.9883 - val_recall: 0.8528 - val_precision: 0.9830
#
# Epoch 00123: saving model to ./checkpoints/
# Epoch 124/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0398 - accuracy: 0.9152 - dice_coef: 0.9416 - IOU: 0.8896 - specificity: 0.9947 - recall: 0.8621 - precision: 0.9945 - val_loss: 0.0778 - val_accuracy: 0.9068 - val_dice_coef: 0.9201 - val_IOU: 0.8521 - val_specificity: 0.9898 - val_recall: 0.8401 - val_precision: 0.9855
#
# Epoch 00124: saving model to ./checkpoints/
# Epoch 125/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0396 - accuracy: 0.9152 - dice_coef: 0.9417 - IOU: 0.8898 - specificity: 0.9949 - recall: 0.8611 - precision: 0.9947 - val_loss: 0.0973 - val_accuracy: 0.9037 - val_dice_coef: 0.9083 - val_IOU: 0.8322 - val_specificity: 0.9910 - val_recall: 0.8140 - val_precision: 0.9866
#
# Epoch 00125: saving model to ./checkpoints/
# Epoch 126/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0393 - accuracy: 0.9152 - dice_coef: 0.9421 - IOU: 0.8905 - specificity: 0.9948 - recall: 0.8631 - precision: 0.9946 - val_loss: 0.0871 - val_accuracy: 0.9055 - val_dice_coef: 0.9187 - val_IOU: 0.8497 - val_specificity: 0.9908 - val_recall: 0.8222 - val_precision: 0.9859
#
# Epoch 00126: saving model to ./checkpoints/
# Epoch 127/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0394 - accuracy: 0.9152 - dice_coef: 0.9420 - IOU: 0.8903 - specificity: 0.9948 - recall: 0.8621 - precision: 0.9946 - val_loss: 0.0678 - val_accuracy: 0.9079 - val_dice_coef: 0.9235 - val_IOU: 0.8579 - val_specificity: 0.9896 - val_recall: 0.8481 - val_precision: 0.9841
#
# Epoch 00127: saving model to ./checkpoints/
# Epoch 128/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0391 - accuracy: 0.9153 - dice_coef: 0.9424 - IOU: 0.8911 - specificity: 0.9949 - recall: 0.8622 - precision: 0.9948 - val_loss: 0.0745 - val_accuracy: 0.9061 - val_dice_coef: 0.9181 - val_IOU: 0.8487 - val_specificity: 0.9877 - val_recall: 0.8440 - val_precision: 0.9801
#
# Epoch 00128: saving model to ./checkpoints/
# Epoch 129/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0397 - accuracy: 0.9152 - dice_coef: 0.9416 - IOU: 0.8896 - specificity: 0.9948 - recall: 0.8623 - precision: 0.9945 - val_loss: 0.1087 - val_accuracy: 0.9007 - val_dice_coef: 0.8972 - val_IOU: 0.8138 - val_specificity: 0.9888 - val_recall: 0.8020 - val_precision: 0.9804
#
# Epoch 00129: saving model to ./checkpoints/
# Epoch 130/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0399 - accuracy: 0.9151 - dice_coef: 0.9413 - IOU: 0.8891 - specificity: 0.9946 - recall: 0.8622 - precision: 0.9943 - val_loss: 0.0816 - val_accuracy: 0.9062 - val_dice_coef: 0.9191 - val_IOU: 0.8504 - val_specificity: 0.9884 - val_recall: 0.8434 - val_precision: 0.9831
#
# Epoch 00130: saving model to ./checkpoints/
# Epoch 131/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0396 - accuracy: 0.9152 - dice_coef: 0.9417 - IOU: 0.8898 - specificity: 0.9948 - recall: 0.8624 - precision: 0.9945 - val_loss: 0.1122 - val_accuracy: 0.9033 - val_dice_coef: 0.9110 - val_IOU: 0.8369 - val_specificity: 0.9911 - val_recall: 0.8091 - val_precision: 0.9875
#
# Epoch 00131: saving model to ./checkpoints/
# Epoch 132/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0389 - accuracy: 0.9153 - dice_coef: 0.9428 - IOU: 0.8918 - specificity: 0.9951 - recall: 0.8618 - precision: 0.9950 - val_loss: 0.1169 - val_accuracy: 0.9028 - val_dice_coef: 0.9082 - val_IOU: 0.8323 - val_specificity: 0.9919 - val_recall: 0.8041 - val_precision: 0.9884
#
# Epoch 00132: saving model to ./checkpoints/
# Epoch 133/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0389 - accuracy: 0.9153 - dice_coef: 0.9427 - IOU: 0.8916 - specificity: 0.9950 - recall: 0.8621 - precision: 0.9948 - val_loss: 0.1491 - val_accuracy: 0.8989 - val_dice_coef: 0.8922 - val_IOU: 0.8059 - val_specificity: 0.9923 - val_recall: 0.7773 - val_precision: 0.9885
#
# Epoch 00133: saving model to ./checkpoints/
# Epoch 134/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0390 - accuracy: 0.9153 - dice_coef: 0.9427 - IOU: 0.8915 - specificity: 0.9951 - recall: 0.8614 - precision: 0.9950 - val_loss: 0.3184 - val_accuracy: 0.8850 - val_dice_coef: 0.8434 - val_IOU: 0.7301 - val_specificity: 0.9882 - val_recall: 0.7247 - val_precision: 0.9788
#
# Epoch 00134: saving model to ./checkpoints/
# Epoch 135/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0396 - accuracy: 0.9152 - dice_coef: 0.9417 - IOU: 0.8898 - specificity: 0.9947 - recall: 0.8625 - precision: 0.9944 - val_loss: 0.1472 - val_accuracy: 0.9004 - val_dice_coef: 0.9010 - val_IOU: 0.8203 - val_specificity: 0.9900 - val_recall: 0.7990 - val_precision: 0.9854
#
# Epoch 00135: saving model to ./checkpoints/
# Epoch 136/200
# 47/47 [==============================] - 16s 340ms/step - loss: 0.0434 - accuracy: 0.9143 - dice_coef: 0.9362 - IOU: 0.8801 - specificity: 0.9937 - recall: 0.8606 - precision: 0.9924 - val_loss: 0.1885 - val_accuracy: 0.8955 - val_dice_coef: 0.8849 - val_IOU: 0.7943 - val_specificity: 0.9884 - val_recall: 0.7832 - val_precision: 0.9823
#
# Epoch 00136: saving model to ./checkpoints/
# Epoch 137/200
# 47/47 [==============================] - 16s 338ms/step - loss: 0.0406 - accuracy: 0.9150 - dice_coef: 0.9403 - IOU: 0.8873 - specificity: 0.9944 - recall: 0.8626 - precision: 0.9939 - val_loss: 0.0811 - val_accuracy: 0.9069 - val_dice_coef: 0.9219 - val_IOU: 0.8553 - val_specificity: 0.9897 - val_recall: 0.8414 - val_precision: 0.9853
#
# Epoch 00137: saving model to ./checkpoints/
# Epoch 138/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0393 - accuracy: 0.9152 - dice_coef: 0.9423 - IOU: 0.8908 - specificity: 0.9948 - recall: 0.8626 - precision: 0.9946 - val_loss: 0.0876 - val_accuracy: 0.9057 - val_dice_coef: 0.9164 - val_IOU: 0.8458 - val_specificity: 0.9899 - val_recall: 0.8341 - val_precision: 0.9861
#
# Epoch 00138: saving model to ./checkpoints/
# Epoch 139/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0387 - accuracy: 0.9154 - dice_coef: 0.9430 - IOU: 0.8922 - specificity: 0.9951 - recall: 0.8622 - precision: 0.9950 - val_loss: 0.1397 - val_accuracy: 0.8995 - val_dice_coef: 0.8953 - val_IOU: 0.8110 - val_specificity: 0.9914 - val_recall: 0.7879 - val_precision: 0.9870
#
# Epoch 00139: saving model to ./checkpoints/
# Epoch 140/200
# 47/47 [==============================] - 16s 339ms/step - loss: 0.0391 - accuracy: 0.9153 - dice_coef: 0.9426 - IOU: 0.8914 - specificity: 0.9950 - recall: 0.8625 - precision: 0.9947 - val_loss: 0.0924 - val_accuracy: 0.9056 - val_dice_coef: 0.9190 - val_IOU: 0.8503 - val_specificity: 0.9892 - val_recall: 0.8344 - val_precision: 0.9847
#
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00140: saving model to ./checkpoints/
# Epoch 00140: early stopping

# %%
hist_df = pd.DataFrame(history.history)
hist_df.to_csv("model_history.csv")

# %%
hist_df
# Out:
#          loss  accuracy  dice_coef       IOU  specificity    recall  \
# 0    0.489583  0.790205   0.442262  0.286782     0.873609  0.694842
# 1    0.297756  0.873290   0.586377  0.415430     0.946409  0.831485
# 2    0.230965  0.881324   0.656555  0.489259     0.959657  0.816305
# 3    0.197777  0.884082   0.698096  0.536511     0.964882  0.806085
# 4    0.172833  0.887852   0.732116  0.577618     0.970170  0.804116
# ..        ...       ...        ...       ...          ...       ...
# 135  0.043385  0.914272   0.936243  0.880137     0.993745  0.860559
# 136  0.040574  0.914956   0.940269  0.887276     0.994412  0.862620
# 137  0.039340  0.915223   0.942254  0.890816     0.994832  0.862583
# 138  0.038704  0.915358   0.943016  0.892182     0.995069  0.862206
# 139  0.039105  0.915267   0.942556  0.891362     0.994951  0.862515
#
#      precision       val_loss  val_accuracy  val_dice_coef   val_IOU  \
# 0     0.657081  391617.812500      0.163279       0.351580  0.213542
# 1     0.870521       3.309942      0.602223       0.447989  0.288950
# 2     0.902649       0.551356      0.758460       0.182888  0.100756
# 3     0.915961       0.628903      0.752279       0.103371  0.054504
# 4     0.930012       0.613535      0.752296       0.111495  0.059041
# ..         ...            ...           ...            ...       ...
# 135   0.992431       0.188516      0.895548       0.884868  0.794331
# 136   0.993933       0.081147      0.906856       0.921935  0.855294
# 137   0.994600       0.087644      0.905712       0.916407  0.845848
# 138   0.994974       0.139733      0.899474       0.895321  0.811031
# 139   0.994744       0.092411      0.905554       0.918979  0.850307
#
#      val_specificity  val_recall  val_precision    lr
# 0           0.000000    1.000000       0.247733  0.01
# 1           0.586035    0.899380       0.425611  0.01
# 2           0.998903    0.036232       0.938467  0.01
# 3           1.000000    0.000064       1.000000  0.01
# 4           1.000000    0.000159       1.000000  0.01
# ..               ...         ...            ...   ...
# 135         0.988450    0.783188       0.982344  0.01
# 136         0.989702    0.841394       0.985313  0.01
# 137         0.989922    0.834108       0.986051  0.01
# 138         0.991434    0.787906       0.986990  0.01
# 139         0.989246    0.834376       0.984653  0.01
#
# [140 rows x 15 columns]

# %%
idx = hist_df['val_accuracy'].idxmax()
print(idx, hist_df['val_accuracy'][idx])
# Out:
# 119 0.9079405069351196

# %%
model.save('attn_unet.h5')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import f1_score
import numpy as np

predict_img1=(pred>0.25)*1
y_test1=(Y_test>0.25)*1
f1_score(predict_img1.flatten(), y_test1.flatten(), average='micro')
# Out:
# 0.9786795339276714

# %%
pred.shape
# Out:
# (93, 512, 512, 1)

# %%
# plt.figure(figsize = (20,10))
plt.title("Predict Mask",fontsize = 40)
plt.imshow(pred[50,:,:,0], cmap='gray')

# %%
plt.title("Original Mask",fontsize = 40)
plt.imshow(Y_test[50,:,:,0], cmap='gray')
