# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization,concatenate,UpSampling2D,Dropout
from tensorflow.keras.models import Model
import tensorflow as tf 
from tensorflow.keras.layers import Input, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, Concatenate, Activation, Add, multiply, add, concatenate, LeakyReLU, ZeroPadding2D, UpSampling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K 
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
mkdir checkpoints

# %%
X = np.load("../input/teeth-segmentation-npy-files/X.npy")
Y = np.load("../input/teeth-segmentation-npy-files/Y.npy")
X.shape, Y.shape
# Out:
# ((464, 512, 512, 1), (464, 512, 512, 1))

# %%
# X = np.reshape(X, (-1,1,512,512))
# X.shape
# Y = np.reshape(Y, (-1,1,512,512))
# Y.shape

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, 
                                                    shuffle=True, 
                                                    random_state=42)

# %%
del X
del Y

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((371, 512, 512, 1), (93, 512, 512, 1), (371, 512, 512, 1), (93, 512, 512, 1))

# %%
#### Attention UNet

def conv_block(x, filter_size, size, dropout, batch_norm = False):
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    return conv


def repeat_elem(tensor, rep):
     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': rep})(tensor)


def gating_signal(input, out_size, batch_norm = False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x


def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
#     print(shape_x, shape_g)
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)
    shape_theta_x = K.int_shape(theta_x)
#     print(shape_theta_x)
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(
        inter_shape, 
        (3, 3),
        strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
        padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn



def Attention_UNet():
    # hyper parameters
    dropout_rate = 0.2
    batch_norm = True
    
    # network structure
    f = [16, 32, 64, 128, 256, 512]
    
    inputs = layers.Input(shape = (512, 512, 1))

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, 3, f[0], dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, 3, f[1], dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, 3, f[2], dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, 3, f[3], dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5
    conv_8 = conv_block(pool_8, 3, f[4], dropout_rate, batch_norm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(conv_8)
    # DownRes 6
    conv_4 = conv_block(pool_4, 3, f[5], dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6
    gating_8 = gating_signal(conv_4, f[4], batch_norm)
    att_8 = attention_block(conv_8, gating_8, f[3])
    up_8 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(conv_4)
    up_8 = layers.concatenate([up_8, att_8], axis=3)
    up_conv_8 = conv_block(up_8, 3, f[4], dropout_rate, batch_norm)
    
    # UpRes 6
    gating_16 = gating_signal(up_conv_8, f[3], batch_norm)
    att_16 = attention_block(conv_16, gating_16, f[3])
    up_16 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, 3, f[3], dropout_rate, batch_norm)

    # UpRes 7
    gating_32 = gating_signal(up_conv_16, f[2], batch_norm)
    att_32 = attention_block(conv_32, gating_32, f[2])
    up_32 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, 3, f[2], dropout_rate, batch_norm)
    
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, f[1], batch_norm)
    att_64 = attention_block(conv_64, gating_64, f[1])
    up_64 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, 3, f[1], dropout_rate, batch_norm)
    
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, f[0], batch_norm)
    att_128 = attention_block(conv_128, gating_128, f[0])
    up_128 = layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, 3, f[0], dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis = 3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = keras.models.Model(inputs, conv_final, name="Attention_UNet")
    return model

model = Attention_UNet()
model.summary()
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 512, 512, 16) 160         input_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 512, 512, 16) 64          conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 512, 512, 16) 0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 512, 512, 16) 2320        activation_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 512, 512, 16) 64          conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 512, 512, 16) 0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 512, 512, 16) 0           activation_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 256, 256, 16) 0           dropout_56[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 256, 256, 32) 4640        max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 256, 256, 32) 128         conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 256, 256, 32) 0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 256, 256, 32) 9248        activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 256, 256, 32) 128         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 256, 256, 32) 0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 256, 256, 32) 0           activation_150[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 128, 128, 32) 0           dropout_57[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 128, 128, 64) 256         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 128, 128, 64) 0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 128, 128, 64) 36928       activation_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 128, 128, 64) 256         conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 128, 128, 64) 0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 128, 128, 64) 0           activation_152[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 64, 64, 64)   0           dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 64, 64, 128)  512         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 64, 64, 128)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 64, 64, 128)  147584      activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 64, 64, 128)  512         conv2d_184[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 64, 64, 128)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 64, 64, 128)  0           activation_154[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 32, 32, 128)  0           dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 32, 32, 256)  1024        conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 32, 32, 256)  0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 32, 32, 256)  590080      activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 32, 32, 256)  1024        conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 32, 32, 256)  0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 32, 32, 256)  0           activation_156[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 16, 16, 256)  0           dropout_60[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 16, 16, 512)  2048        conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 16, 16, 512)  0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 16, 16, 512)  2359808     activation_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 16, 16, 512)  2048        conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 16, 16, 512)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 16, 16, 512)  0           activation_158[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 16, 16, 256)  131328      dropout_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 16, 16, 256)  1024        conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 16, 16, 256)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 16, 16, 128)  32896       activation_159[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 16, 16, 128)  147584      conv2d_191[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 16, 16, 128)  131200      dropout_60[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 128)  0           conv2d_transpose_15[0][0]
#                                                                  conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 16, 16, 128)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 16, 16, 1)    129         activation_160[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 16, 16, 1)    0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 32, 32, 1)    0           activation_161[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 32, 32, 256)  0           up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 32, 32, 256)  0           lambda_9[0][0]
#                                                                  dropout_60[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 32, 32, 256)  65792       multiply_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 32, 32, 512)  0           dropout_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 32, 32, 256)  1024        conv2d_193[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 768)  0           up_sampling2d_19[0][0]
#                                                                  batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 32, 32, 256)  1769728     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 32, 32, 256)  1024        conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 32, 32, 256)  0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 32, 32, 256)  590080      activation_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 32, 32, 256)  1024        conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 32, 32, 256)  0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 32, 32, 256)  0           activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 32, 32, 128)  32896       dropout_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 32, 32, 128)  512         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 32, 32, 128)  0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 32, 32, 128)  16512       activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 32, 32, 128)  147584      conv2d_198[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 32, 32, 128)  65664       dropout_59[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 128)  0           conv2d_transpose_16[0][0]
#                                                                  conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 32, 32, 128)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 32, 32, 1)    129         activation_165[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 32, 32, 1)    0           conv2d_199[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 64, 64, 1)    0           activation_166[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 64, 64, 128)  0           up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 64, 64, 128)  0           lambda_10[0][0]
#                                                                  dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 64, 64, 128)  16512       multiply_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 64, 64, 256)  0           dropout_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 64, 64, 128)  512         conv2d_200[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 384)  0           up_sampling2d_21[0][0]
#                                                                  batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 64, 64, 128)  442496      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 64, 64, 128)  512         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 64, 64, 128)  0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 64, 64, 128)  147584      activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 64, 64, 128)  512         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 64, 64, 128)  0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 64, 64, 128)  0           activation_168[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 64, 64, 64)   8256        dropout_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 64, 64, 64)   256         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 64, 64, 64)   0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 64, 64, 64)   4160        activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 64, 64, 64)   36928       conv2d_205[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 64, 64, 64)   16448       dropout_58[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 64)   0           conv2d_transpose_17[0][0]
#                                                                  conv2d_204[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 64, 64, 64)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 64, 64, 1)    65          activation_170[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 64, 64, 1)    0           conv2d_206[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 128, 128, 1)  0           activation_171[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 128, 128, 64) 0           up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 128, 128, 64) 0           lambda_11[0][0]
#                                                                  dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 128, 128, 64) 4160        multiply_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 128, 128, 128 0           dropout_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 128, 128, 64) 256         conv2d_207[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 192 0           up_sampling2d_23[0][0]
#                                                                  batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 128, 128, 64) 110656      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 128, 128, 64) 256         conv2d_208[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 128, 128, 64) 0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 128, 128, 64) 36928       activation_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 128, 128, 64) 256         conv2d_209[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 128, 128, 64) 0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 128, 128, 64) 0           activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 128, 128, 32) 2080        dropout_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 128, 128, 32) 128         conv2d_210[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 128, 128, 32) 0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 128, 128, 32) 1056        activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 128, 128, 32) 9248        conv2d_212[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 128, 128, 32) 4128        dropout_57[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 128, 128, 32) 0           conv2d_transpose_18[0][0]
#                                                                  conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 128, 128, 32) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 128, 128, 1)  33          activation_175[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 128, 128, 1)  0           conv2d_213[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_24 (UpSampling2D) (None, 256, 256, 1)  0           activation_176[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 256, 256, 32) 0           up_sampling2d_24[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 256, 256, 32) 0           lambda_12[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 256, 256, 32) 1056        multiply_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_25 (UpSampling2D) (None, 256, 256, 64) 0           dropout_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 256, 256, 32) 128         conv2d_214[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 256, 256, 96) 0           up_sampling2d_25[0][0]
#                                                                  batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 256, 256, 32) 27680       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 256, 256, 32) 128         conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 256, 256, 32) 0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 256, 256, 32) 9248        activation_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 256, 256, 32) 128         conv2d_216[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 256, 256, 32) 0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 256, 256, 32) 0           activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 256, 256, 16) 528         dropout_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 256, 256, 16) 64          conv2d_217[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 256, 256, 16) 0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 256, 256, 16) 272         activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 256, 256, 16) 2320        conv2d_219[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 256, 256, 16) 1040        dropout_56[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 256, 256, 16) 0           conv2d_transpose_19[0][0]
#                                                                  conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 256, 256, 16) 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 256, 256, 1)  17          activation_180[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 256, 256, 1)  0           conv2d_220[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_26 (UpSampling2D) (None, 512, 512, 1)  0           activation_181[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 512, 512, 16) 0           up_sampling2d_26[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 512, 512, 16) 0           lambda_13[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 512, 512, 16) 272         multiply_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_27 (UpSampling2D) (None, 512, 512, 32) 0           dropout_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 512, 512, 16) 64          conv2d_221[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 512, 512, 48) 0           up_sampling2d_27[0][0]
#                                                                  batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 512, 512, 16) 6928        concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 512, 512, 16) 64          conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 512, 512, 16) 0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 512, 512, 16) 2320        activation_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 512, 512, 16) 64          conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 512, 512, 16) 0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# dropout_66 (Dropout)            (None, 512, 512, 16) 0           activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 512, 512, 1)  17          dropout_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 512, 512, 1)  4           conv2d_224[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 512, 512, 1)  0           batch_normalization_170[0][0]
# ==================================================================================================
# Total params: 8,758,410
# Trainable params: 8,750,408
# Non-trainable params: 8,002
# __________________________________________________________________________________________________

# %%
from keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return(2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def IOU(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    
    return intersection/union

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred, 1)

def specificity(y_true, y_pred):
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    return tn / (tn + fp + K.epsilon())

# %%
import tensorflow as tf
model_ckt = tf.keras.callbacks.ModelCheckpoint(
    "./checkpoints/",
    monitor='val_accuracy',
    verbose = 1,
    save_best_only=False,
    save_weights_only=True,
    mode='max',
    save_freq='epoch',
)
learningrate_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                           mode = 'max',
                                                           factor = 0.1, 
                                                           patience = 20, 
                                                           verbose = 1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', 
                                                 patience = 20, 
                                                 mode = 'max',
                                                 restore_best_weights = True,
                                                  verbose=1)

callbacks_list = [learningrate_scheduler, early_stopping, model_ckt]

# %%
import tensorflow as tf
import tensorflow_addons as tfa
model.compile(optimizer =tf.keras.optimizers.Adam(learning_rate = 0.01), 
              loss = 'binary_crossentropy', 
              metrics = ['accuracy', dice_coef, IOU, specificity,
                         tf.keras.metrics.Recall(name='recall'),
                         tf.keras.metrics.Precision(name='precision')])

history = model.fit(X_train, Y_train,
          validation_data=(X_test, Y_test),
          batch_size=8,
          epochs=200,
          verbose=1,
          callbacks = callbacks_list)
# Out:
# 2022-09-22 16:28:42.953976: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-09-22 16:28:52.449475: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 47/47 [==============================] - 38s 411ms/step - loss: 0.4689 - accuracy: 0.8074 - dice_coef: 0.4607 - IOU: 0.3019 - specificity: 0.8833 - recall: 0.7429 - precision: 0.6977 - val_loss: 9735.7617 - val_accuracy: 0.1633 - val_dice_coef: 0.3516 - val_IOU: 0.2136 - val_specificity: 6.3380e-05 - val_recall: 1.0000 - val_precision: 0.2477
#
# Epoch 00001: saving model to ./checkpoints/
# Epoch 2/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.2928 - accuracy: 0.8756 - dice_coef: 0.5934 - IOU: 0.4227 - specificity: 0.9512 - recall: 0.8206 - precision: 0.8807 - val_loss: 0.5802 - val_accuracy: 0.7736 - val_dice_coef: 0.2836 - val_IOU: 0.1659 - val_specificity: 0.9913 - val_recall: 0.1420 - val_precision: 0.8951
#
# Epoch 00002: saving model to ./checkpoints/
# Epoch 3/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.2195 - accuracy: 0.8863 - dice_coef: 0.6703 - IOU: 0.5047 - specificity: 0.9646 - recall: 0.8204 - precision: 0.9171 - val_loss: 0.6272 - val_accuracy: 0.7557 - val_dice_coef: 0.1248 - val_IOU: 0.0666 - val_specificity: 0.9999 - val_recall: 0.0177 - val_precision: 0.9987
#
# Epoch 00003: saving model to ./checkpoints/
# Epoch 4/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.1815 - accuracy: 0.8908 - dice_coef: 0.7185 - IOU: 0.5608 - specificity: 0.9707 - recall: 0.8182 - precision: 0.9340 - val_loss: 0.5985 - val_accuracy: 0.7533 - val_dice_coef: 0.1247 - val_IOU: 0.0665 - val_specificity: 1.0000 - val_recall: 0.0053 - val_precision: 0.9996
#
# Epoch 00004: saving model to ./checkpoints/
# Epoch 5/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.1637 - accuracy: 0.8912 - dice_coef: 0.7448 - IOU: 0.5936 - specificity: 0.9734 - recall: 0.8074 - precision: 0.9395 - val_loss: 0.6925 - val_accuracy: 0.7549 - val_dice_coef: 0.0969 - val_IOU: 0.0510 - val_specificity: 0.9999 - val_recall: 0.0139 - val_precision: 0.9976
#
# Epoch 00005: saving model to ./checkpoints/
# Epoch 6/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.1572 - accuracy: 0.8901 - dice_coef: 0.7580 - IOU: 0.6105 - specificity: 0.9720 - recall: 0.8069 - precision: 0.9351 - val_loss: 0.6599 - val_accuracy: 0.7626 - val_dice_coef: 0.1643 - val_IOU: 0.0897 - val_specificity: 0.9995 - val_recall: 0.0530 - val_precision: 0.9889
#
# Epoch 00006: saving model to ./checkpoints/
# Epoch 7/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1427 - accuracy: 0.8928 - dice_coef: 0.7788 - IOU: 0.6379 - specificity: 0.9751 - recall: 0.8079 - precision: 0.9440 - val_loss: 0.7186 - val_accuracy: 0.7574 - val_dice_coef: 0.1116 - val_IOU: 0.0592 - val_specificity: 0.9999 - val_recall: 0.0265 - val_precision: 0.9972
#
# Epoch 00007: saving model to ./checkpoints/
# Epoch 8/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1324 - accuracy: 0.8947 - dice_coef: 0.7944 - IOU: 0.6590 - specificity: 0.9766 - recall: 0.8127 - precision: 0.9488 - val_loss: 0.6003 - val_accuracy: 0.7620 - val_dice_coef: 0.1836 - val_IOU: 0.1015 - val_specificity: 0.9998 - val_recall: 0.0496 - val_precision: 0.9961
#
# Epoch 00008: saving model to ./checkpoints/
# Epoch 9/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.1248 - accuracy: 0.8962 - dice_coef: 0.8066 - IOU: 0.6760 - specificity: 0.9774 - recall: 0.8174 - precision: 0.9520 - val_loss: 0.6817 - val_accuracy: 0.7568 - val_dice_coef: 0.1208 - val_IOU: 0.0644 - val_specificity: 0.9999 - val_recall: 0.0230 - val_precision: 0.9982
#
# Epoch 00009: saving model to ./checkpoints/
# Epoch 10/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.1204 - accuracy: 0.8967 - dice_coef: 0.8140 - IOU: 0.6864 - specificity: 0.9779 - recall: 0.8170 - precision: 0.9538 - val_loss: 0.6637 - val_accuracy: 0.7688 - val_dice_coef: 0.2158 - val_IOU: 0.1213 - val_specificity: 0.9994 - val_recall: 0.0851 - val_precision: 0.9943
#
# Epoch 00010: saving model to ./checkpoints/
# Epoch 11/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1196 - accuracy: 0.8962 - dice_coef: 0.8168 - IOU: 0.6905 - specificity: 0.9783 - recall: 0.8139 - precision: 0.9530 - val_loss: 0.6702 - val_accuracy: 0.7608 - val_dice_coef: 0.1645 - val_IOU: 0.0900 - val_specificity: 0.9998 - val_recall: 0.0428 - val_precision: 0.9973
#
# Epoch 00011: saving model to ./checkpoints/
# Epoch 12/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1125 - accuracy: 0.8983 - dice_coef: 0.8264 - IOU: 0.7043 - specificity: 0.9797 - recall: 0.8189 - precision: 0.9584 - val_loss: 0.7628 - val_accuracy: 0.7628 - val_dice_coef: 0.1539 - val_IOU: 0.0842 - val_specificity: 0.9998 - val_recall: 0.0532 - val_precision: 0.9958
#
# Epoch 00012: saving model to ./checkpoints/
# Epoch 13/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.1086 - accuracy: 0.8990 - dice_coef: 0.8332 - IOU: 0.7141 - specificity: 0.9802 - recall: 0.8205 - precision: 0.9602 - val_loss: 0.8300 - val_accuracy: 0.7566 - val_dice_coef: 0.0917 - val_IOU: 0.0484 - val_specificity: 0.9999 - val_recall: 0.0217 - val_precision: 0.9946
#
# Epoch 00013: saving model to ./checkpoints/
# Epoch 14/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1039 - accuracy: 0.9002 - dice_coef: 0.8404 - IOU: 0.7248 - specificity: 0.9805 - recall: 0.8269 - precision: 0.9614 - val_loss: 0.7921 - val_accuracy: 0.7526 - val_dice_coef: 0.0577 - val_IOU: 0.0297 - val_specificity: 1.0000 - val_recall: 0.0014 - val_precision: 1.0000
#
# Epoch 00014: saving model to ./checkpoints/
# Epoch 15/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.1011 - accuracy: 0.9008 - dice_coef: 0.8446 - IOU: 0.7311 - specificity: 0.9814 - recall: 0.8263 - precision: 0.9636 - val_loss: 0.9320 - val_accuracy: 0.7527 - val_dice_coef: 0.0333 - val_IOU: 0.0169 - val_specificity: 1.0000 - val_recall: 0.0021 - val_precision: 0.9986
#
# Epoch 00015: saving model to ./checkpoints/
# Epoch 16/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0979 - accuracy: 0.9015 - dice_coef: 0.8493 - IOU: 0.7381 - specificity: 0.9818 - recall: 0.8291 - precision: 0.9654 - val_loss: 0.8410 - val_accuracy: 0.7581 - val_dice_coef: 0.1009 - val_IOU: 0.0536 - val_specificity: 0.9998 - val_recall: 0.0296 - val_precision: 0.9892
#
# Epoch 00016: saving model to ./checkpoints/
# Epoch 17/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0960 - accuracy: 0.9018 - dice_coef: 0.8528 - IOU: 0.7433 - specificity: 0.9823 - recall: 0.8278 - precision: 0.9661 - val_loss: 0.7116 - val_accuracy: 0.7813 - val_dice_coef: 0.3005 - val_IOU: 0.1795 - val_specificity: 0.9979 - val_recall: 0.1574 - val_precision: 0.9813
#
# Epoch 00017: saving model to ./checkpoints/
# Epoch 18/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0926 - accuracy: 0.9028 - dice_coef: 0.8580 - IOU: 0.7514 - specificity: 0.9825 - recall: 0.8342 - precision: 0.9675 - val_loss: 0.8670 - val_accuracy: 0.7641 - val_dice_coef: 0.1531 - val_IOU: 0.0837 - val_specificity: 0.9997 - val_recall: 0.0596 - val_precision: 0.9937
#
# Epoch 00018: saving model to ./checkpoints/
# Epoch 19/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0909 - accuracy: 0.9031 - dice_coef: 0.8607 - IOU: 0.7555 - specificity: 0.9832 - recall: 0.8315 - precision: 0.9691 - val_loss: 0.4587 - val_accuracy: 0.8170 - val_dice_coef: 0.5286 - val_IOU: 0.3638 - val_specificity: 0.9955 - val_recall: 0.3471 - val_precision: 0.9809
#
# Epoch 00019: saving model to ./checkpoints/
# Epoch 20/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0920 - accuracy: 0.9025 - dice_coef: 0.8599 - IOU: 0.7543 - specificity: 0.9825 - recall: 0.8318 - precision: 0.9668 - val_loss: 0.7029 - val_accuracy: 0.7940 - val_dice_coef: 0.3882 - val_IOU: 0.2438 - val_specificity: 0.9981 - val_recall: 0.2156 - val_precision: 0.9896
#
# Epoch 00020: saving model to ./checkpoints/
# Epoch 21/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0887 - accuracy: 0.9035 - dice_coef: 0.8646 - IOU: 0.7616 - specificity: 0.9831 - recall: 0.8344 - precision: 0.9694 - val_loss: 0.8883 - val_accuracy: 0.7591 - val_dice_coef: 0.1019 - val_IOU: 0.0542 - val_specificity: 0.9998 - val_recall: 0.0335 - val_precision: 0.9928
#
# Epoch 00021: saving model to ./checkpoints/
# Epoch 22/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0886 - accuracy: 0.9033 - dice_coef: 0.8651 - IOU: 0.7623 - specificity: 0.9835 - recall: 0.8317 - precision: 0.9696 - val_loss: 0.5808 - val_accuracy: 0.8016 - val_dice_coef: 0.4332 - val_IOU: 0.2799 - val_specificity: 0.9975 - val_recall: 0.2579 - val_precision: 0.9888
#
# Epoch 00022: saving model to ./checkpoints/
# Epoch 23/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0902 - accuracy: 0.9026 - dice_coef: 0.8630 - IOU: 0.7591 - specificity: 0.9824 - recall: 0.8332 - precision: 0.9665 - val_loss: 0.3027 - val_accuracy: 0.8601 - val_dice_coef: 0.7346 - val_IOU: 0.5865 - val_specificity: 0.9910 - val_recall: 0.5829 - val_precision: 0.9816
#
# Epoch 00023: saving model to ./checkpoints/
# Epoch 24/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0876 - accuracy: 0.9034 - dice_coef: 0.8668 - IOU: 0.7650 - specificity: 0.9836 - recall: 0.8322 - precision: 0.9698 - val_loss: 0.7932 - val_accuracy: 0.7804 - val_dice_coef: 0.2936 - val_IOU: 0.1740 - val_specificity: 0.9978 - val_recall: 0.1533 - val_precision: 0.9808
#
# Epoch 00024: saving model to ./checkpoints/
# Epoch 25/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0823 - accuracy: 0.9050 - dice_coef: 0.8742 - IOU: 0.7765 - specificity: 0.9843 - recall: 0.8394 - precision: 0.9723 - val_loss: 0.9408 - val_accuracy: 0.7622 - val_dice_coef: 0.1274 - val_IOU: 0.0691 - val_specificity: 0.9997 - val_recall: 0.0503 - val_precision: 0.9929
#
# Epoch 00025: saving model to ./checkpoints/
# Epoch 26/200
# 47/47 [==============================] - 15s 311ms/step - loss: 0.0801 - accuracy: 0.9056 - dice_coef: 0.8779 - IOU: 0.7823 - specificity: 0.9848 - recall: 0.8410 - precision: 0.9739 - val_loss: 0.8257 - val_accuracy: 0.7728 - val_dice_coef: 0.2340 - val_IOU: 0.1340 - val_specificity: 0.9993 - val_recall: 0.1057 - val_precision: 0.9897
#
# Epoch 00026: saving model to ./checkpoints/
# Epoch 27/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0805 - accuracy: 0.9053 - dice_coef: 0.8777 - IOU: 0.7821 - specificity: 0.9847 - recall: 0.8394 - precision: 0.9732 - val_loss: 0.7316 - val_accuracy: 0.7918 - val_dice_coef: 0.3682 - val_IOU: 0.2303 - val_specificity: 0.9979 - val_recall: 0.2066 - val_precision: 0.9863
#
# Epoch 00027: saving model to ./checkpoints/
# Epoch 28/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0826 - accuracy: 0.9045 - dice_coef: 0.8753 - IOU: 0.7784 - specificity: 0.9841 - recall: 0.8378 - precision: 0.9710 - val_loss: 0.3993 - val_accuracy: 0.8423 - val_dice_coef: 0.6798 - val_IOU: 0.5230 - val_specificity: 0.9744 - val_recall: 0.5692 - val_precision: 0.9221
#
# Epoch 00028: saving model to ./checkpoints/
# Epoch 29/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0982 - accuracy: 0.8998 - dice_coef: 0.8551 - IOU: 0.7470 - specificity: 0.9808 - recall: 0.8243 - precision: 0.9610 - val_loss: 1.2689 - val_accuracy: 0.5787 - val_dice_coef: 0.5205 - val_IOU: 0.3527 - val_specificity: 0.5537 - val_recall: 0.8959 - val_precision: 0.4002
#
# Epoch 00029: saving model to ./checkpoints/
# Epoch 30/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0876 - accuracy: 0.9030 - dice_coef: 0.8686 - IOU: 0.7677 - specificity: 0.9832 - recall: 0.8321 - precision: 0.9686 - val_loss: 0.0968 - val_accuracy: 0.8983 - val_dice_coef: 0.8555 - val_IOU: 0.7475 - val_specificity: 0.9765 - val_recall: 0.8495 - val_precision: 0.9522
#
# Epoch 00030: saving model to ./checkpoints/
# Epoch 31/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0814 - accuracy: 0.9049 - dice_coef: 0.8772 - IOU: 0.7812 - specificity: 0.9841 - recall: 0.8398 - precision: 0.9717 - val_loss: 0.3670 - val_accuracy: 0.8409 - val_dice_coef: 0.6512 - val_IOU: 0.4871 - val_specificity: 0.9955 - val_recall: 0.4655 - val_precision: 0.9884
#
# Epoch 00031: saving model to ./checkpoints/
# Epoch 32/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0796 - accuracy: 0.9053 - dice_coef: 0.8793 - IOU: 0.7846 - specificity: 0.9850 - recall: 0.8372 - precision: 0.9738 - val_loss: 0.5982 - val_accuracy: 0.8160 - val_dice_coef: 0.5352 - val_IOU: 0.3678 - val_specificity: 0.9946 - val_recall: 0.3478 - val_precision: 0.9790
#
# Epoch 00032: saving model to ./checkpoints/
# Epoch 33/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0787 - accuracy: 0.9056 - dice_coef: 0.8813 - IOU: 0.7878 - specificity: 0.9848 - recall: 0.8411 - precision: 0.9735 - val_loss: 0.6370 - val_accuracy: 0.7812 - val_dice_coef: 0.3203 - val_IOU: 0.1933 - val_specificity: 0.9988 - val_recall: 0.1483 - val_precision: 0.9915
#
# Epoch 00033: saving model to ./checkpoints/
# Epoch 34/200
# 47/47 [==============================] - 15s 311ms/step - loss: 0.0773 - accuracy: 0.9060 - dice_coef: 0.8827 - IOU: 0.7900 - specificity: 0.9850 - recall: 0.8428 - precision: 0.9744 - val_loss: 1.0251 - val_accuracy: 0.7614 - val_dice_coef: 0.1305 - val_IOU: 0.0706 - val_specificity: 0.9997 - val_recall: 0.0472 - val_precision: 0.9922
#
# Epoch 00034: saving model to ./checkpoints/
# Epoch 35/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0747 - accuracy: 0.9067 - dice_coef: 0.8869 - IOU: 0.7967 - specificity: 0.9856 - recall: 0.8450 - precision: 0.9758 - val_loss: 0.8370 - val_accuracy: 0.7743 - val_dice_coef: 0.2531 - val_IOU: 0.1462 - val_specificity: 0.9993 - val_recall: 0.1139 - val_precision: 0.9915
#
# Epoch 00035: saving model to ./checkpoints/
# Epoch 36/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0730 - accuracy: 0.9072 - dice_coef: 0.8892 - IOU: 0.8005 - specificity: 0.9860 - recall: 0.8458 - precision: 0.9771 - val_loss: 0.5920 - val_accuracy: 0.7901 - val_dice_coef: 0.3779 - val_IOU: 0.2354 - val_specificity: 0.9987 - val_recall: 0.1965 - val_precision: 0.9918
#
# Epoch 00036: saving model to ./checkpoints/
# Epoch 37/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0725 - accuracy: 0.9073 - dice_coef: 0.8903 - IOU: 0.8023 - specificity: 0.9862 - recall: 0.8456 - precision: 0.9773 - val_loss: 1.0134 - val_accuracy: 0.7606 - val_dice_coef: 0.1195 - val_IOU: 0.0641 - val_specificity: 0.9998 - val_recall: 0.0417 - val_precision: 0.9943
#
# Epoch 00037: saving model to ./checkpoints/
# Epoch 38/200
# 47/47 [==============================] - 15s 321ms/step - loss: 0.0759 - accuracy: 0.9062 - dice_coef: 0.8852 - IOU: 0.7942 - specificity: 0.9852 - recall: 0.8427 - precision: 0.9745 - val_loss: 0.9115 - val_accuracy: 0.7726 - val_dice_coef: 0.2348 - val_IOU: 0.1343 - val_specificity: 0.9985 - val_recall: 0.1106 - val_precision: 0.9810
#
# Epoch 00038: saving model to ./checkpoints/
# Epoch 39/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0907 - accuracy: 0.9016 - dice_coef: 0.8671 - IOU: 0.7655 - specificity: 0.9825 - recall: 0.8280 - precision: 0.9651 - val_loss: 0.1728 - val_accuracy: 0.8831 - val_dice_coef: 0.7890 - val_IOU: 0.6516 - val_specificity: 0.9451 - val_recall: 0.8985 - val_precision: 0.8919
#
# Epoch 00039: saving model to ./checkpoints/
# Epoch 40/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0809 - accuracy: 0.9045 - dice_coef: 0.8788 - IOU: 0.7838 - specificity: 0.9841 - recall: 0.8373 - precision: 0.9714 - val_loss: 0.0951 - val_accuracy: 0.8993 - val_dice_coef: 0.8559 - val_IOU: 0.7481 - val_specificity: 0.9772 - val_recall: 0.8554 - val_precision: 0.9548
#
# Epoch 00040: saving model to ./checkpoints/
# Epoch 41/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0744 - accuracy: 0.9066 - dice_coef: 0.8872 - IOU: 0.7973 - specificity: 0.9853 - recall: 0.8451 - precision: 0.9754 - val_loss: 0.2672 - val_accuracy: 0.8662 - val_dice_coef: 0.7568 - val_IOU: 0.6138 - val_specificity: 0.9933 - val_recall: 0.6074 - val_precision: 0.9867
#
# Epoch 00041: saving model to ./checkpoints/
# Epoch 42/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0729 - accuracy: 0.9070 - dice_coef: 0.8895 - IOU: 0.8011 - specificity: 0.9861 - recall: 0.8443 - precision: 0.9768 - val_loss: 0.5168 - val_accuracy: 0.8315 - val_dice_coef: 0.5917 - val_IOU: 0.4303 - val_specificity: 0.9970 - val_recall: 0.4137 - val_precision: 0.9906
#
# Epoch 00042: saving model to ./checkpoints/
# Epoch 43/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0712 - accuracy: 0.9074 - dice_coef: 0.8924 - IOU: 0.8058 - specificity: 0.9861 - recall: 0.8471 - precision: 0.9771 - val_loss: 0.8597 - val_accuracy: 0.7868 - val_dice_coef: 0.3380 - val_IOU: 0.2063 - val_specificity: 0.9988 - val_recall: 0.1794 - val_precision: 0.9909
#
# Epoch 00043: saving model to ./checkpoints/
# Epoch 44/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0709 - accuracy: 0.9075 - dice_coef: 0.8925 - IOU: 0.8060 - specificity: 0.9863 - recall: 0.8473 - precision: 0.9775 - val_loss: 0.5371 - val_accuracy: 0.8304 - val_dice_coef: 0.5898 - val_IOU: 0.4268 - val_specificity: 0.9954 - val_recall: 0.4172 - val_precision: 0.9832
#
# Epoch 00044: saving model to ./checkpoints/
# Epoch 45/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0702 - accuracy: 0.9077 - dice_coef: 0.8942 - IOU: 0.8087 - specificity: 0.9861 - recall: 0.8495 - precision: 0.9773 - val_loss: 0.8731 - val_accuracy: 0.7836 - val_dice_coef: 0.3157 - val_IOU: 0.1892 - val_specificity: 0.9988 - val_recall: 0.1630 - val_precision: 0.9904
#
# Epoch 00045: saving model to ./checkpoints/
# Epoch 46/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0688 - accuracy: 0.9081 - dice_coef: 0.8959 - IOU: 0.8114 - specificity: 0.9865 - recall: 0.8500 - precision: 0.9784 - val_loss: 0.7944 - val_accuracy: 0.7994 - val_dice_coef: 0.4206 - val_IOU: 0.2695 - val_specificity: 0.9981 - val_recall: 0.2451 - val_precision: 0.9894
#
# Epoch 00046: saving model to ./checkpoints/
# Epoch 47/200
# 47/47 [==============================] - 15s 315ms/step - loss: 0.0685 - accuracy: 0.9082 - dice_coef: 0.8968 - IOU: 0.8129 - specificity: 0.9866 - recall: 0.8499 - precision: 0.9789 - val_loss: 0.5741 - val_accuracy: 0.8315 - val_dice_coef: 0.5970 - val_IOU: 0.4309 - val_specificity: 0.9963 - val_recall: 0.4188 - val_precision: 0.9880
#
# Epoch 00047: saving model to ./checkpoints/
# Epoch 48/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0697 - accuracy: 0.9078 - dice_coef: 0.8950 - IOU: 0.8100 - specificity: 0.9865 - recall: 0.8485 - precision: 0.9779 - val_loss: 0.5194 - val_accuracy: 0.8311 - val_dice_coef: 0.5997 - val_IOU: 0.4341 - val_specificity: 0.9948 - val_recall: 0.4242 - val_precision: 0.9818
#
# Epoch 00048: saving model to ./checkpoints/
# Epoch 49/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0733 - accuracy: 0.9067 - dice_coef: 0.8901 - IOU: 0.8019 - specificity: 0.9852 - recall: 0.8463 - precision: 0.9750 - val_loss: 0.1589 - val_accuracy: 0.8893 - val_dice_coef: 0.8435 - val_IOU: 0.7302 - val_specificity: 0.9847 - val_recall: 0.7654 - val_precision: 0.9684
#
# Epoch 00049: saving model to ./checkpoints/
# Epoch 50/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0759 - accuracy: 0.9059 - dice_coef: 0.8863 - IOU: 0.7959 - specificity: 0.9851 - recall: 0.8421 - precision: 0.9738 - val_loss: 0.2408 - val_accuracy: 0.8714 - val_dice_coef: 0.7845 - val_IOU: 0.6471 - val_specificity: 0.9848 - val_recall: 0.6782 - val_precision: 0.9636
#
# Epoch 00050: saving model to ./checkpoints/
# Epoch 51/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0707 - accuracy: 0.9074 - dice_coef: 0.8934 - IOU: 0.8073 - specificity: 0.9858 - recall: 0.8494 - precision: 0.9765 - val_loss: 0.4507 - val_accuracy: 0.8401 - val_dice_coef: 0.6560 - val_IOU: 0.4910 - val_specificity: 0.9921 - val_recall: 0.4866 - val_precision: 0.9766
#
# Epoch 00051: saving model to ./checkpoints/
# Epoch 52/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0671 - accuracy: 0.9085 - dice_coef: 0.8989 - IOU: 0.8163 - specificity: 0.9868 - recall: 0.8507 - precision: 0.9793 - val_loss: 0.5061 - val_accuracy: 0.8383 - val_dice_coef: 0.6391 - val_IOU: 0.4727 - val_specificity: 0.9955 - val_recall: 0.4568 - val_precision: 0.9865
#
# Epoch 00052: saving model to ./checkpoints/
# Epoch 53/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0652 - accuracy: 0.9090 - dice_coef: 0.9016 - IOU: 0.8208 - specificity: 0.9873 - recall: 0.8521 - precision: 0.9805 - val_loss: 0.6837 - val_accuracy: 0.8153 - val_dice_coef: 0.5157 - val_IOU: 0.3502 - val_specificity: 0.9967 - val_recall: 0.3334 - val_precision: 0.9864
#
# Epoch 00053: saving model to ./checkpoints/
# Epoch 54/200
# 47/47 [==============================] - 15s 316ms/step - loss: 0.0639 - accuracy: 0.9093 - dice_coef: 0.9033 - IOU: 0.8237 - specificity: 0.9877 - recall: 0.8537 - precision: 0.9811 - val_loss: 0.7945 - val_accuracy: 0.8045 - val_dice_coef: 0.4513 - val_IOU: 0.2944 - val_specificity: 0.9976 - val_recall: 0.2735 - val_precision: 0.9881
#
# Epoch 00054: saving model to ./checkpoints/
# Epoch 55/200
# 47/47 [==============================] - 15s 312ms/step - loss: 0.0634 - accuracy: 0.9094 - dice_coef: 0.9043 - IOU: 0.8253 - specificity: 0.9878 - recall: 0.8542 - precision: 0.9814 - val_loss: 0.7045 - val_accuracy: 0.8137 - val_dice_coef: 0.5059 - val_IOU: 0.3417 - val_specificity: 0.9980 - val_recall: 0.3156 - val_precision: 0.9914
#
# Epoch 00055: saving model to ./checkpoints/
# Epoch 56/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0625 - accuracy: 0.9096 - dice_coef: 0.9055 - IOU: 0.8273 - specificity: 0.9880 - recall: 0.8547 - precision: 0.9819 - val_loss: 0.6196 - val_accuracy: 0.8219 - val_dice_coef: 0.5573 - val_IOU: 0.3892 - val_specificity: 0.9969 - val_recall: 0.3649 - val_precision: 0.9880
#
# Epoch 00056: saving model to ./checkpoints/
# Epoch 57/200
# 47/47 [==============================] - 15s 311ms/step - loss: 0.0621 - accuracy: 0.9098 - dice_coef: 0.9064 - IOU: 0.8288 - specificity: 0.9881 - recall: 0.8550 - precision: 0.9820 - val_loss: 0.5887 - val_accuracy: 0.8333 - val_dice_coef: 0.6142 - val_IOU: 0.4465 - val_specificity: 0.9958 - val_recall: 0.4301 - val_precision: 0.9874
#
# Epoch 00057: saving model to ./checkpoints/
# Epoch 58/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0621 - accuracy: 0.9097 - dice_coef: 0.9062 - IOU: 0.8285 - specificity: 0.9883 - recall: 0.8530 - precision: 0.9824 - val_loss: 0.6258 - val_accuracy: 0.8332 - val_dice_coef: 0.6165 - val_IOU: 0.4493 - val_specificity: 0.9949 - val_recall: 0.4336 - val_precision: 0.9838
#
# Epoch 00058: saving model to ./checkpoints/
# Epoch 59/200
# 47/47 [==============================] - 15s 313ms/step - loss: 0.0610 - accuracy: 0.9100 - dice_coef: 0.9081 - IOU: 0.8317 - specificity: 0.9882 - recall: 0.8567 - precision: 0.9825 - val_loss: 0.5253 - val_accuracy: 0.8430 - val_dice_coef: 0.6619 - val_IOU: 0.4978 - val_specificity: 0.9953 - val_recall: 0.4813 - val_precision: 0.9875
#
# Epoch 00059: saving model to ./checkpoints/
# Epoch 60/200
# 47/47 [==============================] - 15s 314ms/step - loss: 0.0601 - accuracy: 0.9102 - dice_coef: 0.9095 - IOU: 0.8340 - specificity: 0.9887 - recall: 0.8555 - precision: 0.9834 - val_loss: 0.5910 - val_accuracy: 0.8339 - val_dice_coef: 0.6198 - val_IOU: 0.4524 - val_specificity: 0.9950 - val_recall: 0.4390 - val_precision: 0.9852
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00060: saving model to ./checkpoints/
# Epoch 00060: early stopping

# %%
hist_df = pd.DataFrame(history.history)
hist_df.to_csv("model_history.csv")

# %%
hist_df
# Out:
#         loss  accuracy  dice_coef       IOU  specificity    recall  precision  \
# 0   0.450455  0.820355   0.474960  0.313550     0.896323  0.760343   0.727560
# 1   0.290987  0.875754   0.595037  0.424317     0.952237  0.817141   0.884332
# 2   0.224095  0.884350   0.665434  0.499282     0.963364  0.815992   0.913132
# 3   0.186783  0.888928   0.711588  0.552617     0.969597  0.813589   0.929563
# 4   0.163327  0.891686   0.745043  0.593829     0.971958  0.818439   0.936564
# ..       ...       ...        ...       ...          ...       ...        ...
# 78  0.041259  0.914909   0.938681  0.884454     0.994244  0.865978   0.993499
# 79  0.041153  0.914905   0.938939  0.884909     0.994232  0.865810   0.993420
# 80  0.040702  0.915006   0.939567  0.886025     0.994569  0.864780   0.993862
# 81  0.040501  0.915043   0.939944  0.886696     0.994484  0.866342   0.993713
# 82  0.040470  0.915038   0.940208  0.887168     0.994393  0.866578   0.993595
#
#       val_loss  val_accuracy  val_dice_coef   val_IOU  val_specificity  \
# 0   558.288940      0.166633       0.352510  0.214229         0.004260
# 1     0.522300      0.772877       0.281332  0.164480         0.993273
# 2     0.564281      0.753278       0.148015  0.079942         0.999968
# 3     0.607701      0.753153       0.120493  0.064120         0.999974
# 4     0.550638      0.754620       0.164087  0.089400         0.999854
# ..         ...           ...            ...       ...              ...
# 78    0.108038      0.902336       0.907056  0.830332         0.992201
# 79    0.221942      0.886169       0.853226  0.745419         0.994381
# 80    0.241642      0.885594       0.850160  0.740668         0.993299
# 81    0.154512      0.897529       0.893964  0.809033         0.993351
# 82    0.175709      0.894101       0.882915  0.791120         0.991647
#
#     val_recall  val_precision    lr
# 0     1.000000       0.248567  0.01
# 1     0.130187       0.910111  0.01
# 2     0.005501       0.994998  0.01
# 3     0.004929       0.997754  0.01
# 4     0.012607       0.972191  0.01
# ..         ...            ...   ...
# 78    0.806439       0.989185  0.01
# 79    0.706626       0.991087  0.01
# 80    0.709839       0.989758  0.01
# 81    0.772029       0.991356  0.01
# 82    0.763588       0.988075  0.01
#
# [83 rows x 15 columns]

# %%
idx = hist_df['val_accuracy'].idxmax()
print(idx, hist_df['val_accuracy'][idx])
# Out:
# 39 0.8993496894836426

# %%
model.save('attn_unet_5.h5')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import f1_score
import numpy as np

predict_img1=(pred>0.25)*1
y_test1=(Y_test>0.25)*1
f1_score(predict_img1.flatten(), y_test1.flatten(), average='micro')
# Out:
# 0.9524388877294396

# %%
pred.shape
# Out:
# (93, 512, 512, 1)

# %%
# plt.figure(figsize = (20,10))
plt.title("Predict Mask",fontsize = 40)
plt.imshow(pred[50,:,:,0], cmap='gray')

# %%
plt.title("Original Mask",fontsize = 40)
plt.imshow(Y_test[50,:,:,0], cmap='gray')
